# %% [markdown]
# # **Credit Card Customer Segmentation**

# %% [markdown]
# ### **Creator Profile**
# 1. Gina Nur Rahmasari - ginanurahmasari@gmail.com | [LinkedIn](https://www.linkedin.com/in/gina-nur-rahmasari-4ab0a4b7/) | [GitHub](https://github.com/ginanurahmasari)
# 2. Herdiansyah Prihatna Putra - herdiansyahprihatna@gmail.com | [LinkedIn](https://www.linkedin.com/in/herdiansyahp/) | [GitHub](https://github.com/HerdiansyahPP)
# 3. Saniyya Hanan Rosyida - saniyya.rosyida@gmail.com | [LinkedIn](https://www.linkedin.com/in/saniyya-hanan-rosyida/) | [GitHub](https://github.com/saniyyarosyida)

# %% [markdown]
# ### **Content**
# 1. Business Problem Understanding
# 2. Data Understanding
# 3. Data Preprocessing
# 4. Modeling and Evaluation
# 5. Conclusion
# 6. Recommendation
# 7. Business Implementation

# %% [markdown]
# ## **I. Business Problem Understanding**
# #### **Context**
# Dilansir dari [US Bank](https://www.usbank.com/credit-cards/how-credit-cards-work.html#:~:text=Credit%20cards%20offer%20you%20a,loan%20amount%20in%20the%20future.), kartu kredit merupakan instrumen yang dikeluarkan oleh pihak Bank atau lembaga keuangan sejenis yang memungkinkan pemilik kartu kredit untuk melakukan pembayaran non tunai, mentransfer saldo dan menarik uang tunai menggunakan uang milik bank yang tertera dalam sebuah kartu kredit. Tiap jenis kartu kredit memiliki limit saldo yang berbeda-beda. Kepemilikan jenis kartu kredit biasanya disesuaikan dengan penghasilan customer, riwayat penggunaan kartu kredit dan jumlah aset yang dimiliki. Semakin besar penghasilan dan kepemilikan aset, serta semakin loyal, konsumtif dan bertanggung jawab seorang customer dalam riwayat penggunaan kredit, akan memungkinkan bagi bank untuk memberikan limit kredit yang semakin besar atau bahkan tak terbatas. Setiap kegiatan transaksi yang dilakukan menggunakan kartu kredit wajib dibayarkan kembali kepada pihak bank di masa mendatang sesuai dengan tenggat waktu yang diberikan. Seorang customer dapat membayar tagihan kredit secara lunas atau dengan pembayaran minimum namun dikenakan bunga. Jika seorang customer terlambat/tidak membayar tagihannya, maka jumlah tagihannya akan dikenakan bunga dan denda oleh pihak bank dan jika hal ini terus terjadi akan beresiko untuk diturunkan limitnya atau di-blacklist. Dengan demikian, customer yang loyal, konsumtif, dan selalu membayar tagihan kreditnya menjadi kunci bagi pemberi kredit agar bisnis tetap berjalan lancar dan tidak terjadi kredit macet.
#
# Berdasarkan survei yang dilakukan oleh [Forbes Advisor](https://www.forbes.com/advisor/credit-cards/credit-card-statistics/#:~:text=Most%20Common%20Types%20of%20Credit,52.8%25%20of%20cards%20in%20circulation.) pada Februari 2023, hanya 9% warga USA yang masih aktif menggunakan uang tunai untuk bertransaksi, 54% orang lebih memilih menggunakan kartu debit fisik atau virtual, dan 36% lainnya menggunakan kartu kredit fisik atau virtual. Hal ini membuktikan bahwa pola transaksi jual beli di masyarakat telah beralih dari tunai menjadi non tunai, sebab proses pembayarannya yang lebih simpel dan akurat. Beberapa alasan seseorang lebih memilih kartu kredit untuk bertransaksi adalah adanya credit reward, ingin membangun credit score, serta kenyamanan dan keamanan dalam bertransaksi. 4 kartu kredit yang paling umum digunakan di USA adalah Visa, Mastercard, American Express, dan Discover.
#
# Berdasarkan artikel [Money Geek](https://www.moneygeek.com/credit-cards/advice/how-credit-card-companies-make-money/) dan [Joe Resendiz](https://www.valuepenguin.com/how-do-credit-card-companies-make-money), Bank memperoleh keuntungan dari bisnis kartu kredit melalui :
# - Bunga dan denda yang dikenakan ketika customer telat membayar tagihan.
# - Bunga dari peminjaman baik sekali bayar, cicilan, maupun tunai.
# - Biaya penarikan uang tunai / cash advance. Seringkali Bank membebankan biaya yang lebih tinggi untuk tarik tunai.
# - Biaya transfer saldo dari satu kartu kredit ke kartu kredit lain.
# - Biaya transaksi luar negeri.
# - Biaya yang dibayarkan merchant untuk setiap barang/aset yang terjual melalui transaksi dengan kredit.
#
# Bertumbuhnya jumlah pengguna kartu kredit dari tahun ke tahun menyebabkan persaingan bisnis kartu kredit semakin ketat. Pelanggan dapat dengan mudah beralih ke kartu kredit lain yang memiliki biaya keseluruhan paling rendah. Oleh karena itu, penting bagi perusahaan kartu kredit untuk memahami karakteristik pelanggannya kemudian membangun loyalitas dan perilaku konsumtif pelanggan berdasarkan karakteristiknya, sebab mempertahankan pelanggan yang sudah ada lebih murah dibandingkan dengan mendapatkan pelanggan baru. Dilansir dari [SendPulse](https://sendpulse.com/support/glossary/customer-loyalty), pelanggan yang loyal dalam menggunakan kartu kredit sangat penting bagi Bank karena pelanggan tersebut cenderung melakukan pembayaran dengan kredit secara berulang-ulang dan pengeluaran lebih besar saat liburan, sehingga lebih banyak menghasilkan keuntungan daripada pelanggan yang lebih memilih untuk bertransaksi non kredit.
#
# #### **Problem Statement & Goals**
# American Gold Bank adalah sebuah Bank penyedia layanan kartu kredit di USA. Bank tersebut ingin mengetahui karakteristik pelanggannya yang sudah ada kemudian menentukan strategi pemasaran yang tepat untuk dapat membangun loyalitas pelanggan dalam menggunakan produk mereka. Hal ini berguna agar penawaran produk/reward menjadi tepat sasaran sehingga kebutuhan dan kepuasan pelanggan dapat terpenuhi, Bank dapat membangun pelanggan yang masih kurang menguntungkan maupun yang sudah loyal menjadi lebih menguntungkan, serta Bank tidak membuang-buang waktu maupun biaya kepada pelanggan yang merugikan.
#
# Jika pelanggan yang sudah ada tidak dipertahankan, pelanggan dapat beralih ke kartu kredit lain dan menyebabkan keuntungan bisnis menurun, citra bisnis buruk akibat penilaian dari pelanggan kurang baik, dan dalam jangka waktu panjang ketidakpuasan pelanggan akan memengaruhi respon pasar terhadap konten pemasaran yang diterbitkan sehingga membuat penetrasi produk ke pasar menjadi sulit dan Bank tidak dapat menghadapi persaingan perbankan.
#
# #### **Analytic Approach (Model & Metric Evaluation)**
# Selaku Data Scientist di American Gold Bank, kami akan menyelesaikan permasalahan ini dengan men-segmentasi pelanggan berdasarkan riwayat penggunaan kartu kreditnya. Dari sini, kita dapat melihat tingkat loyalitas, perilaku konsumtif dan tanggung jawab pelanggan saat membayar tagihan kredit. Oleh karena itu, model akan dibuat menggunakan metode clustering. Beberapa algoritma clustering yang akan digunakan adalah K-Means, Agglomerative dan DBSCAN (Density-based spatial clustering of applications with noise).
#
# Metric evaluasi yang akan digunakan adalah silhouette score untuk setiap model. Metric silhouette score mengevaluasi model berdasarkan tingkat kemiripan sebuah data poin dengan clusternya sendiri terhadap cluster lain. Jika nilai silhouette score semakin mendekati angka 1, maka semakin jelas perbedaan antar tiap cluster / dapat menjadi tolak ukur untuk melihat apakah pelanggan kartu kredit telah benar-benar tersegmentasi dengan jelas berdasarkan perilaku penggunaan kredit. Jika pelanggan tersegmentasi dengan baik, maka pemberian dan penerapan strategi bisnis untuk tiap segmen pelanggan menjadi lebih tepat sasaran, sehingga dapat meminimalisir waktu, tenaga dan pengeluaran biaya yang sia-sia. Kami juga menggunakan membership untuk melihat jumlah anggota pada tiap cluster yang telah dibuat, sehingga penentuan model terbaik tak hanya berdasarkan nilai metric evaluasinya saja. Terkadang, ada model yang memiliki nilai evaluasi baik namun jumlah anggota pada tiap clusternya sangat jauh berbeda. Penggunaan membership dapat menghindari hal tersebut. Visualisasi boxplot dari hasil clustering juga akan menjadi pertimbangan untuk melihat perbedaan antara 1 cluster dengan cluster lain. Model dengan silhouette score terbaik dengan hasil cluster yang jelas terlihat perbedaannya dan proporsi cluster yang tidak mendiskriminasi cluster lain dapat dipertimbangkan sebagai model terbaik.

# %% [markdown]
# ## **II. Data Understanding**
# Permasalahan di atas akan dianalisa menggunakan dataset **Credit Card for Clustering**. Dataset ini diupload oleh Arjun Bhasin di situs kaggle pada tahun 2018 dan berisi data riwayat perilaku pemegang kartu kredit aktif selama 6 bulan. Dataset dapat diakses [di sini.](https://www.kaggle.com/datasets/arjunbhasin2013/ccdata)

# %% [markdown]
# #### **Exploratory Data Analysis (EDA)**

# %%
# Dataframe
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# Preprocessing
from sklearn.preprocessing import RobustScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# ML Algorithm & Metrics
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import ward, complete, average
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer

# Ignore Warning
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
df = pd.read_csv('CC GENERAL.csv')
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# **Dataset Information**
#
# | Variabel Perilaku | Data Type | Description |
# | --- | --- | --- |
# | CUST_ID | Object | ID customer |
# | BALANCE | Float | Jumlah saldo kredit yang tersisa pada 1 akun customer (Dollar USA) |
# | BALANCE_FREQUENCY | Float | Frekuensi saldo kredit terupdate (Range 0-1, semakin besar nilai semakin sering frekuensinya) |
# | PURCHASES | Float | Total transaksi pembelian menggunakan kartu kredit (one off dan installment) dalam 1 akun selama 6 bulan terakhir (Dollar USA) |
# | ONEOFF_PURCHASES | Float | Total transaksi pembelian yang dilakukan dengan sekali pembayaran (one off) menggunakan kartu kredit (Dollar USA) |
# | INSTALLMENTS_PURCHASES | Float | Total transaksi pembelian yang dilakukan dengan cicilan pembayaran (installment) menggunakan kartu kredit (Dollar USA) |
# | CASH_ADVANCE | Float | Total penarikan tunai (Dollar USA) |
# | PURCHASES_FREQUENCY | Float | Frekuensi pembelian menggunakan metode One off dan installment (Range 0-1, semakin besar nilai semakin sering frekuensinya) |
# | ONEOFFPURCHASESFREQUENCY | Float | Frekuensi pembelian menggunakan metode one off (Range 0-1, semakin besar nilai semakin sering frekuensinya) |
# | PURCHASESINSTALLMENTSFREQUENCY | Float | Frekuensi pembelian menggunakan metode installment (Range 0-1, semakin besar nilai semakin sering frekuensinya) |
# | CASHADVANCEFREQUENCY | Float | Frekuensi penarikan tunai (semakin besar nilai semakin sering frekuensinya) |
# | CASHADVANCETRX | Integer | Jumlah transaksi penarikan tunai |
# | PURCHASES_TRX | Integer | Jumlah transaksi pembelian menggunakan kartu kredit (one off dan installment) |
# | CREDIT_LIMIT | Float | Total maksimum saldo kredit dalam 1 akun customer selama masa kredit aktif dalam 6 bulan (Dollar USA) |
# | PAYMENTS | Float | Total pembayaran tagihan yang telah dilakukan customer (Dollar USA) |
# | MINIMUM_PAYMENTS | Float | Total pembayaran minimum tagihan yang telah dilakukan customer (Dollar USA) |
# | PRCFULLPAYMENT | Float | Persentase pembayaran tagihan secara lunas yang telah dilakukan customer (Range 0-1, semakin besar nilai semakin tinggi persentasenya) |
# | TENURE | Integer | Tenor / jangka waktu layanan kartu kredit untuk pengguna (bulan) |

# %% [markdown]
# Dataset ini tidak memiliki target dan sesuai dengan tujuan penyelesaian masalah yaitu segmentasi pelanggan, maka pembuatan machine learning akan dilakukan menggunakan metode clustering. Melalui dataset ini, kita dapat menganalisis dan mensegmentasikan pelanggan berdasarkan beberapa variabel perilaku pelanggan saat menggunakan kartu kredit, seperti :
# - Loyalitas pelanggan dalam menggunakan kartu kredit. Hal ini dapat diukur dari jumlah transaksi dan frekuensi purchase maupun cash advance, serta frekuensi terupdatenya balance. Semakin sering seorang pelanggan melakukan transaksi pembelian dengan kredit dan penarikan tunai, maka semakin sering balance terupdate, dan dapat dikatakan pelanggan tersebut loyal.
# - Apakah seorang pelanggan lebih menyukai bertransaksi dengan sekali pembayaran (one off) / cicilan (installment).
# - Apakah seorang pelanggan lebih sering bertransaksi dengan kartu kredit atau tarik tunai kredit.
# - Apakah seorang pelanggan dapat dikategorikan sebagai customer yang bertanggung jawab, terlihat dari tagihan yang sudah dibayarkan dan persentase pembayaran tagihan kredit secara lunas. Pelanggan yang memiliki riwayat pembelian dengan kartu kredit atau cash namun tak pernah melakukan pembayaran dapat dikategorikan sebagai pelanggan yang merugikan perusahaan.
# - Seberapa konsumtif seorang pelanggan dapat diukur dari besarnya nominal pembelian dengan kredit dan nominal cash yang dipinjam.

# %%
# Number of rows & columns
print(f'Jumlah baris : {df.shape[0]}')
print(f'Jumlah kolom : {df.shape[1]}')
# Out:
# Jumlah baris : 8950
# Jumlah kolom : 18

# %%
# Data Summary
df.info(verbose= True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
# Numerical & Categorical Description Analysis
display(df.describe(), df.describe(include='object'))
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
# Check number of unique in each column
pd.set_option('display.max_colwidth', 1)

listItem = []
for col in df.columns :
    listItem.append( [col, df[col].nunique()])

tabel1Desc = pd.DataFrame(columns=['Column Name', 'Number of Unique'],
                     data=listItem)
tabel1Desc
# Out:
#                          Column Name  Number of Unique
# 0   CUST_ID                           8950
# 1   BALANCE                           8871
# 2   BALANCE_FREQUENCY                 43
# 3   PURCHASES                         6203
# 4   ONEOFF_PURCHASES                  4014
# 5   INSTALLMENTS_PURCHASES            4452
# 6   CASH_ADVANCE                      4323
# 7   PURCHASES_FREQUENCY               47
# 8   ONEOFF_PURCHASES_FREQUENCY        47
# 9   PURCHASES_INSTALLMENTS_FREQUENCY  47
# 10  CASH_ADVANCE_FREQUENCY            54
# 11  CASH_ADVANCE_TRX                  65
# 12  PURCHASES_TRX                     173
# 13  CREDIT_LIMIT                      205
# 14  PAYMENTS                          8711
# 15  MINIMUM_PAYMENTS                  8636
# 16  PRC_FULL_PAYMENT                  47
# 17  TENURE                            7

# %% [markdown]
# - Dataset ini terdiri dari 8950 data pelanggan kartu kredit di USA dengan 1 kolom ID pelanggan, 1 kolom limit kredit dan 16 kolom yang menggambarkan perilaku pelanggan, seperti kecondongan bertransaksi secara kredit/tunai, proses transaksi dan pembayaran tagihan yang dipilih, dan frekuensi penggunaan kartu kredit. Seluruh data diatas menggambarkan perilaku penggunaan kartu kredit selama 6 bulan di tahun 2018.

# %% [markdown]
# | Tipe Variabel | Jumlah Variabel | Nama Variabel |
# | --- | --- | --- |
# | Variabel Numerik | 17 | balance, balance_frequency, purchases, oneoff_purchases, installments_purchases, cash_advance, purchases_frequency, oneoff_purchases_frequency, purchases_installments_frequency, cash_advance_frequency, cash_advance_trx, purchases_trx, credit_limit, payments, minimum_payments, prc_full_payment dan tenure |
# | Variabel Categorical/Object | 1 | cust_id |

# %% [markdown]
# - Tipe data untuk setiap kolom telah sesuai, yaitu untuk data frekuensi, persentase dan data dengan satuan uang sebagai float, ID sebagai object serta tenor dan jumlah transaksi sebagai integer, sehingga tidak diperlukan data type formatting.
# - Tidak terdapat data yang bernilai negatif, dimana uang, waktu tenor, jumlah transaksi, frekuensi dan persentase tidak dapat bernilai negatif.
# - Pengupload dataset tidak menjelaskan jenis mata uang yang digunakan. Melihat limit kredit yang terdata berkisar antara 50-30.000 maka dapat diperkirakan bahwa mata uang yang digunakan adalah dollar. Mengacu pada data biro kredit Eqiufax yang diterbitkan [CNBC](https://www.cnbc.com/select/average-credit-limits-for-first-credit-card/), rata-rata kredit limit untuk pemilik kartu kredit baru berada di antara 5000 - 6000 USD  dan kredit limit terendah yaitu 200 USD pada tahun 2018 dan 2019. Laporan Experian dalam [Forbes](https://www.forbes.com/advisor/credit-cards/average-credit-card-limit/) juga menyebutkan bahwa rata-rata kredit limit yang dimiliki oleh warga Amerika berada pada 30.000 USD dan limit terendahnya adalah 300 USD ditahun 2020. Sehingga hal ini bisa menjadi dasar untuk menentukan bahwa dataset yang kita gunakan menggunakan satuan mata uang USD. Informasi ini juga dapat menjadi acuan untuk seleksi data limit kredit yang tidak sesuai.

# %% [markdown]
# #### **Check Null Value**

# %%
# Calculate Null
data_null = df.isna().sum().reset_index().rename(columns={'index':'variable',0:'null count'})
# Calculate Percentage Null
data_null['null percentage'] = data_null['null count'].apply(lambda x: (x/(df.shape[0]))*100)
data_null
# Out:
#                             variable  null count  null percentage
# 0   CUST_ID                           0           0.000000
# 1   BALANCE                           0           0.000000
# 2   BALANCE_FREQUENCY                 0           0.000000
# 3   PURCHASES                         0           0.000000
# 4   ONEOFF_PURCHASES                  0           0.000000
# 5   INSTALLMENTS_PURCHASES            0           0.000000
# 6   CASH_ADVANCE                      0           0.000000
# 7   PURCHASES_FREQUENCY               0           0.000000
# 8   ONEOFF_PURCHASES_FREQUENCY        0           0.000000
# 9   PURCHASES_INSTALLMENTS_FREQUENCY  0           0.000000
# 10  CASH_ADVANCE_FREQUENCY            0           0.000000
# 11  CASH_ADVANCE_TRX                  0           0.000000
# 12  PURCHASES_TRX                     0           0.000000
# 13  CREDIT_LIMIT                      1           0.011173
# 14  PAYMENTS                          0           0.000000
# ...

# %% [markdown]
# Terdapat 1 missing value pada kolom credit limit dan 313 missing value pada kolom minimum payments. Persentase missing value pada kedua kolom sangat kecil yaitu sebesar 0.01% untuk credit limit dan 3.49% untuk minimum payments. Treatment untuk menangani missing value akan dilakukan sesuai kondisi data dan keterkaitannya terhadap kolom lain.

# %% [markdown]
# #### **Check Duplicates**

# %%
# Check Duplicates
print('Jumlah data duplikat:', df.duplicated().sum())
# Out:
# Jumlah data duplikat: 0

# %%
df.describe(include='object')
# Out:
#        CUST_ID
# count   8950
# unique  8950
# top     C10001
# freq    1

# %% [markdown]
# Tidak terdapat data duplikat. Hal ini terlihat juga dari frekuensi ID yang paling sering muncul adalah 1 dan jumlah data unik ID sama dengan jumlah data pelanggan kartu kredit yang terdaftar dalam dataset.

# %% [markdown]
# #### **Bivariate Analysis**

# %%
fig, axes = plt.subplots(2,2, figsize=(12,12))

sns.scatterplot(x=df['BALANCE'], y=df['CREDIT_LIMIT'], ax=axes[0,0])
sns.scatterplot(x=df['BALANCE'], y=df['PURCHASES'], ax=axes[0,1])
sns.scatterplot(x=df['BALANCE'], y=df['CASH_ADVANCE'], ax=axes[1,0])
sns.scatterplot(x=df['BALANCE'], y=df['PAYMENTS'], ax=axes[1,1])
# Out:
# <Axes: xlabel='BALANCE', ylabel='PAYMENTS'>

# %% [markdown]
# Dari visualisasi diatas diperoleh informasi bahwa:
# - Sebagian besar customer memiliki balance setara atau kurang dari credit limit yang dimiliki, namun terdapat beberapa pelanggan yang memiliki Balance lebih tinggi dibandingkan Credit Limit-nya. Hal ini berarti beberapa pelanggan memiliki pinjaman lebih dari credit limit yang dimiliki.
# - Terlihat beberapa customer tidak memiliki riwayat pembelian dengan kartu kredit (purchases = 0) namun memiliki balance lebih dari 0, yang berarti customer tersebut mempunyai pinjaman. Hal ini mengindikasikan bahwa terdapat pelanggan yang memakai kartu kredit-nya hanya untuk melakukan penarikan tunai (cash advance) saja.
# - Beberapa data pelanggan menunjukan nilai purchase yang tinggi namun balance-nya rendah artinya customer telah membayar sebagian besar tagihan bill-nya.
# - Terdapat customer yang memiliki Cash Advance 0 dengan Balance yang tinggi, hal ini kemungkinan dikarenakan customer hanya memakai kartu kredit-nya untuk pembelian barang menggunakan kartu (purchase) dan tidak pernah melakukan penarikan tunai (cash advance).
# - Sebagian customer memiliki nilai payments 0 namun memiliki pinjaman (balance > 0), yang artinya pelanggan tersebut tidak pernah membayar tagihannya selama 6 bulan.

# %%
fig, axes = plt.subplots(1,3, figsize=(20,6))

sns.scatterplot(x=df['CREDIT_LIMIT'], y=df['PURCHASES'], ax=axes[0])
sns.scatterplot(x=df['CREDIT_LIMIT'], y=df['CASH_ADVANCE'], ax=axes[1])
sns.scatterplot(x=df['CREDIT_LIMIT'], y=df['PAYMENTS'], ax=axes[2])
# Out:
# <Axes: xlabel='CREDIT_LIMIT', ylabel='PAYMENTS'>

# %% [markdown]
# Dari visualisasi diatas diperoleh informasi:
# - Grafik pertama menunjukkan bahwa sebagian besar pelanggan memiliki total pembelian dengan kartu kredit dibawah 10.000 USD. Sebagian pelanggan melakukan purchase kurang dari atau setara dengan kredit limit yang dimiliki, namun beberapa pelanggan lainnya memiliki riwayat total pembelian dengan kartu kredit yang melebihi kredit limitnya.
# - Grafik kedua menunjukkan bahwa mayoritas customer memiliki riwayat tarik tunai dibawah 10.000 USD, namun sebagian lainnya memiliki Cash Advance yang lebih tinggi dibandingkan Credit Limit-nya.
# - Grafik ketiga menunjukkan bahwa sebagian besar customer melakukan pembayaran tagihan setara atau kurang dari besar kredit limit yang dimiliki, sedangkan sebagian lainnya membayar tagihan kredit melebihi credit limit-nya. Terlihat juga bahwa mayoritas pelanggan membayar tagihan kurang dari 10.000 USD karena sesuai dengan mayoritas besaran purchase dan cash advance yaitu kurang dari 10.000 USD

# %% [markdown]
# Mari kita bahas beberapa penemuan diatas lebih lanjut dengan melihat kondisi data secara lebih detail.

# %% [markdown]
# #### **Check Customer with Balance more than Credit Limit**

# %%
df1 = df[df['BALANCE'] > df['CREDIT_LIMIT']]
df1
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5     C10006  1809.828751  1.0                1333.28    0.0
# 10    C10011  1293.124939  1.0                920.12     0.0
# 20    C10021  2016.684686  1.0                176.68     0.0
# 64    C10067  1923.886805  1.0                1887.64    0.0
# 78    C10082  1205.716678  1.0                0.00       0.0
# ...      ...          ...  ...                 ...       ...
# 8589  C18823  1283.337407  1.0                1022.41    171.6
# 8614  C18848  1182.080141  1.0                266.68     0.0
# 8624  C18858  1012.089680  1.0                312.48     0.0
# 8724  C18961  3002.791004  1.0                2463.00    2463.0
# 8873  C19114  1023.883008  1.0                585.84     0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5     1333.28                 0.000000      0.666667
# 10    920.12                  0.000000      1.000000
# ...

# %% [markdown]
# Terdapat 227 pelanggan yang memiliki balance yang lebih besar dari kredit limit. Dilansir dari [Investopedia](https://www.investopedia.com/terms/c/credit-card-balance.asp), balance kredit seseorang akan berubah/ter-update ketika pelanggan melakukan transaksi menggunakan kartu kredit dan melakukan pembayaran tagihan. Balance akan bertambah ketika pelanggan melakukan peminjaman ke bank dan akan berkurang ketika melunasi hutangnya.
#
# Balance yang lebih besar dari credit limit dianggap valid karena terdapat kemungkinan seorang customer menyetujui overlimit yang ditawarkan pihak bank diawal pembuatan kartu kredit. Dalam [Forbes](https://www.forbes.com/advisor/credit-cards/what-happens-if-you-go-over-credit-limit/) disebutkan bahwa overlimit credit merupakan salah satu kebijakan bank dimana ketika customer melakukan transaksi hingga melebihi credit limit-nya, akan dibebankan biaya tambahan berupa overlimit fee yang menjadi keuntungan tambahan bagi bank. Jika customer tidak mengizinkan overlimit maka ketika transaksi melebihi credit limit, transaksi akan ditolak oleh bank. Oleh karena itu, data pelanggan diatas akan dibiarkan saja karena merupakan kejadian yang normal terjadi di dunia pengkreditan.

# %% [markdown]
# #### **Check Customer with Loan more than Credit Limit**
# Total pinjaman merupakan gabungan antara data purchases (karena telah mewakili riwayat pembelian secara one off dan installment) dan cash advance.

# %%
df2 = df[(df['PURCHASES']+df['CASH_ADVANCE']) > df['CREDIT_LIMIT']]
df2
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 12    C10013  1516.928620  1.000000           3217.99    2500.23
# 23    C10024  3800.151377  0.818182           4248.35    3454.56
# 40    C10041  663.447810   0.727273           0.00       0.00
# 41    C10043  784.889762   0.909091           1526.59    786.30
# 51    C10053  1078.888565  1.000000           3107.85    2221.74
# ...      ...          ...       ...               ...        ...
# 8912  C19153  376.547421   0.857143           520.00     280.00
# 8915  C19156  381.341657   1.000000           78.00      0.00
# 8923  C19164  486.661842   0.833333           1898.88    939.09
# 8933  C19174  735.652303   1.000000           619.60     255.62
# 8949  C19190  372.708075   0.666667           1093.25    1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 12    717.76                  0.000000      1.000000
# 23    793.79                  7974.415626   1.000000
# ...

# %%
print('Mean balance frequency :',df2['BALANCE_FREQUENCY'].mean())
print('Median balance frequency :',df2['BALANCE_FREQUENCY'].median())
# Out:
# Mean balance frequency : 0.9406829595426561
# Median balance frequency : 1.0

# %% [markdown]
# Terdapat 1.137 pelanggan yang memiliki pinjaman lebih dari limit kredit yang dimiliki. Nilai purchases dan cash advance dapat melebihi limit kredit karena beberapa pelanggan melakukan pembayaran sebelum billing date kemudian melakukan purchase kembali sehingga memungkinkan total purchase lebih besar dari besar limit kredit yang dimiliki. Customer seperti ini merupakan customer loyal dan menguntungkan bagi bank karena sering melakukan peminjaman dan selalu melakukan pembayaran tagihan kreditnya, dapat terlihat juga dari rata-rata dan median balance frequency yang tinggi yang artinya sering ter-update baik itu dari purchase maupun payment. Oleh karena itu, data diatas akan dibiarkan.

# %% [markdown]
# #### **Check Customer with Payment more than Credit Limit**

# %%
df3 = df[(df['PAYMENTS'] > df['CREDIT_LIMIT'])]
df3
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 22    C10023  132.342240   0.636364           815.90     0.00
# 23    C10024  3800.151377  0.818182           4248.35    3454.56
# 39    C10040  1411.602230  0.454545           963.24     963.24
# 40    C10041  663.447810   0.727273           0.00       0.00
# 53    C10055  464.674156   0.888889           1979.22    1979.22
# ...      ...         ...        ...               ...        ...
# 8897  C19138  328.686581   1.000000           2806.78    2588.53
# 8898  C19139  379.288635   0.714286           550.00     50.00
# 8911  C19152  30.709172    0.285714           693.42     0.00
# 8914  C19155  181.891981   0.500000           0.00       0.00
# 8938  C19179  78.818407    0.500000           0.00       0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 22    815.90                  0.000000      1.000000
# 23    793.79                  7974.415626   1.000000
# ...

# %% [markdown]
# Terdapat 1.132 customer yang melakukan pembayaran melebihi credit limit-nya. Hal ini dapat terjadi pada customer yang menyetujui overlimit atau yang melakukan pembayaran sebelum billing date lalu melakukan purchase/cash advance kembali. Customer seperti ini juga merupakan customer yang sangat menguntungkan bagi bank karena jumlah transaksinya tinggi dan bertanggung jawab dalam membayar tagihan kreditnya.

# %% [markdown]
# #### **Check Customer with Payments more than Purchases and Cash Advance**

# %%
df4 = df[df['PAYMENTS'] > (df['PURCHASES'] + df['CASH_ADVANCE'])]
df4
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001  40.900749    0.818182           95.40      0.0
# 4     C10005  817.714335   1.000000           16.00      16.0
# 5     C10006  1809.828751  1.000000           1333.28    0.0
# 7     C10008  1823.652743  1.000000           436.20     0.0
# 10    C10011  1293.124939  1.000000           920.12     0.0
# ...      ...          ...       ...              ...     ...
# 8934  C19175  20.260716    0.833333           110.50     0.0
# 8938  C19179  78.818407    0.500000           0.00       0.0
# 8943  C19184  5.871712     0.500000           20.90      20.9
# 8945  C19186  28.493517    1.000000           291.12     0.0
# 8948  C19189  13.457564    0.833333           0.00       0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0     95.40                   0.000000      0.166667
# 4     0.00                    0.000000      0.083333
# ...

# %% [markdown]
# Terdapat 4.172 Pelanggan yang melakukan pembayaran tagihan lebih dari total purchases dan cash advance. Hal ini mungkin saja terjadi ketika pelanggan membayar hutang dari bulan-bulan sebelumnya yang tidak terdaftar dalam dataset, sedangkan data purchases dan cash advance hanya berasal dari 6 bulan terakhir, sehingga data ini akan dibiarkan.

# %% [markdown]
# #### **Check Customer Who Never Pay**
# Pelanggan yang tidak pernah melakukan pembayaran adalah :
# - Pelanggan yang memang tidak pernah membayar karena tidak punya tagihan.
# - Pelanggan yang memiliki riwayat purchases, cash advance, dan balance diatas 0 namun memiliki payments 0. Pelanggan dengan kategori ini lah yang merugikan perusahaan.

# %%
# Check seluruh pelanggan yang tidak melakukan pembayaran
df5 = df[df['PAYMENTS'] == 0]
df5
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 3     C10004  1666.670542  0.636364           1499.00    1499.00
# 45    C10047  2242.311686  1.000000           437.00     97.00
# 47    C10049  3910.111237  1.000000           0.00       0.00
# 55    C10057  1311.995984  1.000000           1283.90    1283.90
# 56    C10058  3625.218146  1.000000           313.27     313.27
# ...      ...          ...       ...              ...        ...
# 8854  C19095  3.833185     0.125000           45.00      45.00
# 8919  C19160  14.524779    0.333333           152.00     152.00
# 8929  C19170  371.527312   0.333333           0.00       0.00
# 8935  C19176  183.817004   1.000000           465.90     0.00
# 8944  C19185  193.571722   0.833333           1012.73    1012.73
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 3     0.0                     205.788017    0.083333
# 45    340.0                   184.648692    0.333333
# ...

# %%
# Check pelanggan yang punya riwayat pinjaman namun tak pernah membayar tagihan
df6 = df[(df['PURCHASES'] + df['CASH_ADVANCE'] != 0) & (df['PAYMENTS'] == 0) | (df['BALANCE'] != 0) & (df['PAYMENTS'] == 0)]
df6
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 3     C10004  1666.670542  0.636364           1499.00    1499.00
# 45    C10047  2242.311686  1.000000           437.00     97.00
# 47    C10049  3910.111237  1.000000           0.00       0.00
# 55    C10057  1311.995984  1.000000           1283.90    1283.90
# 56    C10058  3625.218146  1.000000           313.27     313.27
# ...      ...          ...       ...              ...        ...
# 8854  C19095  3.833185     0.125000           45.00      45.00
# 8919  C19160  14.524779    0.333333           152.00     152.00
# 8929  C19170  371.527312   0.333333           0.00       0.00
# 8935  C19176  183.817004   1.000000           465.90     0.00
# 8944  C19185  193.571722   0.833333           1012.73    1012.73
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 3     0.0                     205.788017    0.083333
# 45    340.0                   184.648692    0.333333
# ...

# %% [markdown]
# Terlihat bahwa jumlah pelanggan yang tidak melakukan pembayaran adalah  240 orang dan pelanggan yang tidak membayar tagihannya juga 240 orang. Hal ini berarti pelanggan dengan payments 0 hanyalah pelanggan yang memang menunggak tagihannya. 240 pelanggan ini memiliki pinjaman dari pengambilan tunai maupun purchases namun tidak pernah melakukan pembayaran selama 6 bulan. Pelanggan tersebut dapat dikategorikan sebagai pelanggan yang merugikan bank karena berpotensi mengakibatkan kredit macet. [Sean Fox](https://www.bankrate.com/personal-finance/credit/when-does-old-debt-fall-off-credit-report/#collections), seorang co-president dari Freedom Debt Relief di U.S. mengatakan bahwa jika pemilik kartu kredit tidak membayarkan hutangnya selama 180 hari (6 bulan) setelah tanggal jatuh tempo pembayaran, kreditur sangat mungkin untuk menjual hutangnya ke agen penagihan. Langkah ini menunjukkan bahwa kreditur telah memutuskan untuk menyerah untuk mendapatkan pembayaran sendiri. Menjual ke agen penagihan adalah cara untuk meminimalkan kerugian kreditur. Dengan demikian, seluruh pelanggan tersebut akan didrop agar pemberian strategi bisnis hanya akan terfokus pada pelanggan yang masih bertanggung jawab terhadap tagihan kreditnya.

# %% [markdown]
# ## **III. Data Preprocessing**

# %% [markdown]
# ### **1) Handle Missing Value**

# %% [markdown]
# ##### **Credit Limit**
#
# Terdapat 1 null value pada kolom kredit limit dan akan didrop karena :
# - Tidak ada informasi jenis kartu kredit, sehingga limit sulit ditentukan
# - Total nominal transaksi tidak menjamin besaran limit kredit seseorang karena purchases dan cash advance dapat lebih tinggi dari credit limit jika customer melakukan pembayaran tagihan sebelum billing date dan melakukan purchase kembali.

# %%
# Drop null in credit limit
df = df.dropna(subset=['CREDIT_LIMIT'])
df.shape
# Out:
# (8949, 18)

# %% [markdown]
# ##### **Minimum Payments**
#
# Data minimum payments memiliki keterkaitan dengan data payments. Setelah diteliti, dari 313 data yang memiliki null pada minimum paymentsnya dapat dibagi menjadi 2 jenis pelanggan:
# - Tipe 1 : Pelanggan yang tidak pernah melakukan pembayaran (payments=0) sebanyak 240 orang. Data null untuk customer tipe 1 dapat dipastikan minimum paymentsnya juga 0 karena tidak pernah membayar. Meski begitu, pelanggan tersebut hanyalah pelanggan yang menyebabkan kredit macet sehingga datanya akan di drop.
# - Tipe 2 : Pelanggan yang pernah melakukan pembayaran sebanyak 73 orang. Data null dengan tipe ini akan didrop karena sulit untuk mendeteksi total pembayaran minimum dari seluruh tagihan yang sudah dibayarkan. Pengisian menggunakan median pada null value juga kurang tepat karena kita tidak dapat menyamaratakan pembayaran minimum yang dilakukan oleh 73 pelanggan, karena total purchase dan cash advancenya juga berbeda-beda.

# %%
# Check customer with zero payments / with null type 1
df6 = df[df['PAYMENTS'] == 0]
print('Total customer with zero payments :', df6.count()[1])
print('Min payment unique in customer with zero payments:', df6['MINIMUM_PAYMENTS'].unique())
print(df6[['CUST_ID','PAYMENTS','MINIMUM_PAYMENTS']].to_markdown())
# Out:
# Total customer with zero payments : 240
# Min payment unique in customer with zero payments: [nan]
# |      | CUST_ID   |   PAYMENTS |   MINIMUM_PAYMENTS |
# |-----:|:----------|-----------:|-------------------:|
# |    3 | C10004    |          0 |                nan |
# |   45 | C10047    |          0 |                nan |
# |   47 | C10049    |          0 |                nan |
# |   55 | C10057    |          0 |                nan |
# |   56 | C10058    |          0 |                nan |
# |   63 | C10065    |          0 |                nan |
# |   93 | C10098    |          0 |                nan |
# |   94 | C10099    |          0 |                nan |
# |   97 | C10102    |          0 |                nan |
# |  103 | C10108    |          0 |                nan |
# |  111 | C10116    |          0 |                nan |
# |  121 | C10126    |          0 |                nan |
# |  129 | C10135    |          0 |                nan |
# ...

# %%
# Drop Null Type 1 & 2
df = df.dropna(subset=['MINIMUM_PAYMENTS'])

# %%
# Recheck Null
print(df.shape)
data_null = df.isna().sum().reset_index().rename(columns={'index':'variable',0:'null count'})
data_null['null percentage'] = data_null['null count'].apply(lambda x: (x/(df.shape[0]))*100)
data_null
# Out:
# (8636, 18)
#                             variable  null count  null percentage
# 0   CUST_ID                           0           0.0
# 1   BALANCE                           0           0.0
# 2   BALANCE_FREQUENCY                 0           0.0
# 3   PURCHASES                         0           0.0
# 4   ONEOFF_PURCHASES                  0           0.0
# 5   INSTALLMENTS_PURCHASES            0           0.0
# 6   CASH_ADVANCE                      0           0.0
# 7   PURCHASES_FREQUENCY               0           0.0
# 8   ONEOFF_PURCHASES_FREQUENCY        0           0.0
# 9   PURCHASES_INSTALLMENTS_FREQUENCY  0           0.0
# 10  CASH_ADVANCE_FREQUENCY            0           0.0
# 11  CASH_ADVANCE_TRX                  0           0.0
# 12  PURCHASES_TRX                     0           0.0
# 13  CREDIT_LIMIT                      0           0.0
# 14  PAYMENTS                          0           0.0
# 15  MINIMUM_PAYMENTS                  0           0.0
# ...

# %% [markdown]
# ### **2) Drop Column CUST_ID**
# Dataset tidak memiliki data duplikat, oleh karena itu kolom ID pelanggan akan dihapus karena data ID terdiri dari nilai yang berurutan dan akan menyebabkan kesalahan hasil interpretasi jika diikutsertakan dalam pemodelan. Selanjutnya, Kolom ID akan digabungkan dengan dataframe setelah final model diterapkan untuk mendapatkan informasi siapa saja pelanggan yang tergolong pada masing-masing segmen.

# %%
# Drop Customer ID
df = df.drop(['CUST_ID'], axis=1)

# %%
# Kolom customer ID telah terhapus
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8636 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8636 non-null   float64
#  1   BALANCE_FREQUENCY                 8636 non-null   float64
#  2   PURCHASES                         8636 non-null   float64
#  3   ONEOFF_PURCHASES                  8636 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8636 non-null   float64
#  5   CASH_ADVANCE                      8636 non-null   float64
#  6   PURCHASES_FREQUENCY               8636 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8636 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8636 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8636 non-null   float64
#  10  CASH_ADVANCE_TRX                  8636 non-null   int64
# ...

# %% [markdown]
# ### **3) Handle Invalid Data**

# %% [markdown]
# #### **Credit Limit**
# Mengacu pada data biro kredit Eqiufax dan laporan Experian yang telah disebutkan saat EDA, maka data pelanggan yang memiliki limit kredit kurang dari 200 USD tidak akan dipakai karena tidak sesuai dengan kenyataan yang terjadi dan dapat dianggap sebagai anomali. Setelah diteliti lebih lanjut ternyata terdapat 6 data saja yang termasuk dalam kategori ini.

# %%
df[df['CREDIT_LIMIT'] < 200]
# Out:
#          BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2493  112.010460  1.000000           229.0      229.0
# 3469  348.813275  1.000000           0.0        0.0
# 5508  70.794108   0.909091           0.0        0.0
# 6546  151.704474  1.000000           0.0        0.0
# 6565  45.226140   0.727273           0.0        0.0
# 6951  795.497557  0.909091           0.0        0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2493  0.0                     0.000000      0.181818
# 3469  0.0                     27.740449     0.000000
# 5508  0.0                     211.854586    0.000000
# 6546  0.0                     87.794993     0.000000
# 6565  0.0                     146.123548    0.000000
# 6951  0.0                     5676.779668   0.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2493  0.181818                    0.0
# 3469  0.000000                    0.0
# 5508  0.000000                    0.0
# ...

# %%
df = df[df['CREDIT_LIMIT'] >= 200]
print(df.shape)
# Out:
# (8630, 17)

# %% [markdown]
# ### **4) Handle Outliers**

# %%
# Generate boxplot for each columns (exc. CUST_ID)
fig, axes = plt.subplots(6, 3, figsize=(24,24))

for i, j in zip(df.select_dtypes('number').columns, axes.flatten()):
    sns.boxplot(data=df, x= i, ax= j)
plt.gca().axis('off')
plt.show()

# %% [markdown]
# Hasil visualisasi boxplot setelah proses cleaning menunjukkan bahwa seluruh kolom memiliki outlier kecuali kolom PURCHASES_FREQUENCY dan PURCHASES_INSTALLMENT_FREQUENCY. Dari sini juga dapat terlihat bahwa hanya kolom PURCHASES_FREQUENCY yang datanya terdistribusi normal. Data pada kolom balance_frequency dan tenure terdistribusi left-skewed dan sisanya terdistribusi right-skewed. Outlier akan dibiarkan sebab pada kenyataannya, penggunaan dan pembayaran kredit oleh tiap pelanggan tidak dapat diatur sedemikian rupa, dan sesuai dengan penjelasan EDA sebelumnya, data diatas merupakan fenomena yang normal terjadi.

# %% [markdown]
# ### **5) Recheck duplicate, null value, data type, shape and description after preprocessing**

# %%
# Recheck Duplicates
print('Jumlah data duplikat:', df.duplicated().sum())
# Out:
# Jumlah data duplikat: 0

# %%
# Recheck Null
data_null = df.isna().sum().reset_index().rename(columns={'index':'variable',0:'null count'})
data_null['null percentage'] = data_null['null count'].apply(lambda x: (x/(df.shape[0]))*100)
data_null
# Out:
#                             variable  null count  null percentage
# 0   BALANCE                           0           0.0
# 1   BALANCE_FREQUENCY                 0           0.0
# 2   PURCHASES                         0           0.0
# 3   ONEOFF_PURCHASES                  0           0.0
# 4   INSTALLMENTS_PURCHASES            0           0.0
# 5   CASH_ADVANCE                      0           0.0
# 6   PURCHASES_FREQUENCY               0           0.0
# 7   ONEOFF_PURCHASES_FREQUENCY        0           0.0
# 8   PURCHASES_INSTALLMENTS_FREQUENCY  0           0.0
# 9   CASH_ADVANCE_FREQUENCY            0           0.0
# 10  CASH_ADVANCE_TRX                  0           0.0
# 11  PURCHASES_TRX                     0           0.0
# 12  CREDIT_LIMIT                      0           0.0
# 13  PAYMENTS                          0           0.0
# 14  MINIMUM_PAYMENTS                  0           0.0
# 15  PRC_FULL_PAYMENT                  0           0.0
# ...

# %%
# Recheck Data Summary
df.info(verbose= True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8630 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8630 non-null   float64
#  1   BALANCE_FREQUENCY                 8630 non-null   float64
#  2   PURCHASES                         8630 non-null   float64
#  3   ONEOFF_PURCHASES                  8630 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8630 non-null   float64
#  5   CASH_ADVANCE                      8630 non-null   float64
#  6   PURCHASES_FREQUENCY               8630 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8630 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8630 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8630 non-null   float64
#  10  CASH_ADVANCE_TRX                  8630 non-null   int64
# ...

# %%
# Recheck Data Description
df.describe().T
# Out:
#                                    count         mean          std  \
# BALANCE                           8630.0  1602.161544  2095.987154
# BALANCE_FREQUENCY                 8630.0  0.895015     0.207752
# PURCHASES                         8630.0  1026.120271  2167.703683
# ONEOFF_PURCHASES                  8630.0  605.295460   1684.825451
# INSTALLMENTS_PURCHASES            8630.0  421.136124   917.496865
# CASH_ADVANCE                      8630.0  994.154058   2121.485660
# PURCHASES_FREQUENCY               8630.0  0.496324     0.401220
# ONEOFF_PURCHASES_FREQUENCY        8630.0  0.206031     0.300117
# PURCHASES_INSTALLMENTS_FREQUENCY  8630.0  0.369077     0.398112
# CASH_ADVANCE_FREQUENCY            8630.0  0.137582     0.201816
# CASH_ADVANCE_TRX                  8630.0  3.314832     6.914638
# PURCHASES_TRX                     8630.0  15.043221    25.186340
# CREDIT_LIMIT                      8630.0  4525.142310  3658.681113
# ...

# %% [markdown]
# - Jumlah data pelanggan setelah cleaning : 8630 orang
# - Model ini hanya dapat digunakan pada data pelanggan dengan nilai maximum dan minimum pada tiap variabel berikut / penggunaannya menjadi tidak valid jika nilai datanya diluar jangkauan ini:
#     1. BALANCE : 0 hingga 19.043 USD
#     1. BALANCE_FREQUENCY : 0 hingga 1
#     1. PURCHASES : 0 hingga 49.039 USD
#     1. ONEOFF_PURCHASES : 0 hingga 40.761 USD
#     1. INSTALLMENTS_PURCHASES : 0 hingga 22.500 USD
#     1. CASH_ADVANCE : 0 hingga 47.137 USD
#     1. PURCHASES_FREQUENCY : 0 hingga 1
#     1. ONEOFF_PURCHASES_FREQUENCY : 0 hingga 1
#     1. PURCHASES_INSTALLMENTS_FREQUENCY : 0 hingga 1
#     1. CASH_ADVANCE_FREQUENCY : 0 hingga 1.5
#     1. CASH_ADVANCE_TRX : 0 hingga 123 kali transaksi
#     1. PURCHASES_TRX : 0 hingga 358 kali transaksi
#     1. CREDIT_LIMIT : 200 hingga 30.000 USD
#     1. PAYMENTS : 0.049513 hingga 50.721 USD
#     1. MINIMUM_PAYMENTS : 0.019163 hingga 76.406 USD
#     1. PRC_FULL_PAYMENT : 0 hingga 1
#     1. TENURE : 6 hingga 12 bulan
# - Model juga hanya berlaku untuk data pelanggan periode 6 bulan, tidak boleh kurang atau lebih.

# %% [markdown]
# ### **6) Feature Engineering**
# Berikut adalah beberapa Feature engineering yang akan dilakukan :
#
# #### **1) Scaling**
#
# Scaling akan diterapkan pada seluruh model (K-Means, Agglomerative dan DBSCAN) karena ketiga algoritma tersebut memanfaatkan fungsi jarak saat mengelompokkan data. Metode scaling yang akan digunakan adalah Robust scaler karena metodenya yang dapat mentransformasi data menggunakan Q1 dan Q3 sehingga scaling tidak akan terpengaruhi oleh data outlier yang memiliki nilai rentang besar / cocok untuk data yang distribusinya tidak normal.
#
# #### **2) Handle Multicollinearity**
# Multikolinearitas timbul ketika terdapat kolom yang berkorelasi dengan lebih dari 2 kolom lain dalam dataset. Dalam supervised learning, adanya multikolinearitas antara variabel independen dapat menjadi masalah karena model sulit untuk  membagi dampak individual variabel secara akurat pada variabel dependen. Berbeda dengan clustering yang tidak memiliki variabel dependen. Diantara seluruh algoritma yang akan digunakan, hanya K-means yang membutuhkan asumsi tidak adanya multikolinearitas.
#
# Berdasarkan penelitian yang dilakukan oleh [Rajan Sambandam](https://trcmarketresearch.com/whitepaper/cluster-analysis-gets-complicated/), ketika variabel yang digunakan dalam clustering K-Means bersifat kolinear, variabel tersebut akan mendapatkan bobot yang lebih tinggi daripada variabel lain yang kolinearitasnya lebih rendah. Dan jika dua variabel berkorelasi sempurna, maka kedua variabel tersebut secara efektif mewakili konsep yang sama. Hal ini dapat menimbulkan adanya kesenjangan besar antara hasil clustering dengan apa yang terjadi dalam kenyataan, sehingga mengarah pada hasil segmentasi yang tidak diinginkan.
#
# Terdapat 2 jenis atribut yang menyebabkan multikolinearitas, yaitu atribut yang tidak relevan dan redundant/sia-sia.
# - Atribut yang tidak relevan dengan tujuan pemecahan masalah dan menyebabkan kolinearitas harus ditangani sebelum memulai segmentasi. Domain knowledge dapat menjadi pertimbangan dalam menseleksi fitur.
# - Atribut yang redundant dapat ditangani dengan :
#   - Eliminasi Variable : Jika korelasi antar 2 fitur sangat tinggi (>0,80), maka dapat dihilangkan salah satunya karena telah dianggap mewakilkan. Variabel yang dipertahankan dalam segmentasi harus dipilih berdasarkan perannya terhadap permasalahan.
#   - PCA, dengan PCA kita dapat memperoleh beberapa fitur baru yang secara statistik tidak saling berkorelasi, kemudian fitur-fitur yang paling merepresentasikan data-lah yang akan digunakan untuk modeling. Beberapa hal yang perlu dipertimbangkan saat menggunakan PCA adalah ukuran dataset, scaling, dan jumlah komponen/fitur yang akan digunakan. Meski begitu, dalam kasus ini, penggunaan PCA untuk mereduksi multikolinearitas data menjadi opsi terakhir karena berdasarkan beberapa pengalaman yang dibagikan di [Stack Overflow](https://stackoverflow.com/questions/59494747/does-correlation-important-factor-in-unsupervised-learning-clustering#:~:text=The%20short%20answer%20is%20no,variables%20is%20a%20good%20thing) dan [Stack Exchange](https://stats.stackexchange.com/questions/271979/does-applying-pca-result-in-loss-of-information), PCA dapat menyebabkan terjadinya 'information loss'. PCA lebih baik digunakan pada dataset berukuran besar karena dapat mengurangi komputasi juga.

# %% [markdown]
# **Data Multicollinearity**

# %%
# Check multicollinearity
def calc_vif(df):
    vif = pd.DataFrame()
    vif['variable']= df.columns
    vif['VIF'] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    vif['Acceptable'] = np.where(vif.VIF < 4, 'yes', 'no')
    return(vif)

calc_vif(df).sort_values(by = 'VIF', ascending = False)
# Out:
#                             variable           VIF Acceptable
# 2   PURCHASES                         58509.773545  no
# 3   ONEOFF_PURCHASES                  32612.422820  no
# 4   INSTALLMENTS_PURCHASES            10357.272400  no
# 6   PURCHASES_FREQUENCY               26.527705     no
# 1   BALANCE_FREQUENCY                 23.073188     no
# 16  TENURE                            20.629231     no
# 8   PURCHASES_INSTALLMENTS_FREQUENCY  17.210213     no
# 7   ONEOFF_PURCHASES_FREQUENCY        5.690004      no
# 9   CASH_ADVANCE_FREQUENCY            4.966378      no
# 12  CREDIT_LIMIT                      4.698991      no
# 11  PURCHASES_TRX                     4.242591      no
# 0   BALANCE                           4.162568      no
# 10  CASH_ADVANCE_TRX                  3.897750      yes
# 13  PAYMENTS                          3.781196      yes
# 5   CASH_ADVANCE                      3.537091      yes
# 15  PRC_FULL_PAYMENT                  1.737090      yes
# ...

# %% [markdown]
# **Data Correlation**

# %%
# Data Correlation
correlation = df.corr(method='spearman') # Spearman because most of the data distribution are not normal 

fig, ax = plt.subplots()
ax.figure.set_size_inches(15, 15)

mask = np.triu(np.ones_like(correlation))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(correlation, cmap=cmap, square=True, mask=mask, linewidths=.5, annot_kws={'size':14},
            annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# Setelah dilakukan uji multikolinearitas, diperoleh bahwa sebagian besar kolom menunjukkan multikolinearitas. Multikolinearitas terbesar ditunjukkan pada kolom purchases, one off purchases dan installment purchases yang berarti ketiga kolom tersebut paling berkaitan dengan kolom-kolom lainnya. Hal ini dapat terjadi karena:
# - one off dan installment purchases merupakan bagian dari purchases dan korelasi antar keduanya sangat kuat:
#     - one off purchases terhadap purchases : 0.75
#     - installment purchases terhadap purchases : 0.71
# - terdapat kolom frequency yang menjelaskan frekuensi transaksi pembelian secara keseluruhan (purchases) maupun secara masing-masing (one off dan installment purchases). Nilai korelasi antara tiap kolom nominal purchases dengan frekuensi purchasesnya sangat kuat:
#     - purchases terhadap purchases frequency : 0.79
#     - one off purchases terhadap one off purchases frequency : 0.95
#     - installment purchases terhadap intsallment purchases frequency : 0.92
# - terdapat kolom trx yang menjelaskan jumlah transaksi pembelian secara keseluruhan (purchases). Informasi pada kolom ini dapat digunakan untuk perhitungan frekuensi pembelian dan semakin banyak jumlah transaksi memungkinkan bagi pelanggan untuk memiliki nominal pembelian yang lebih besar, sehingga korelasinya terhadap purchases frequency sebesar 0.92 dan terhadap purchases sebesar 0.89.
# - Ketiga kolom tersebut berkaitan dengan balance karena mempengaruhi nominal pinjaman / meningkatkan balance, juga berkaitan dengan payments karena semakin besar pinjaman, maka semakin besar pula tagihan yang dibayarkan.

# %% [markdown]
# **Dasar Pemilihan Fitur**
#
# **1) Seleksi atribut yang tidak relevan**
# Setelah menyeleksi pelanggan-pelanggan yang tidak bertanggung jawab dalam membayarkan hutangnya, segmentasi pelanggan menitikberatkan pada beberapa faktor berikut :
# - Loyalitas & perilaku konsumtif :
#   - BALANCE_FREQUENCY : Semakin sering balance terupdate menandakan semakin sering seorang pelanggan melakukan purchases, cash advance dan pembayaran.
#   - PURCHASES_FREQUENCY, PURCHASES_TRX : Semakin sering seorang pelanggan melakukan purchases, maka semakin loyal dan konsumtif pelanggan tersebut.
#   - PURCHASES_INSTALLMENTS_FREQUENCY : Semakin sering seorang pelanggan melakukan cicilan, maka semakin loyal dan konsumtif pelanggan tersebut dan semakin menguntungkan bagi bank karena adanya bunga cicilan.
#   - PURCHASES_ONEOFF_FREQUENCY : Semakin sering seorang pelanggan melakukan pembelian sekali bayar, maka semakin loyal dan konsumtif pelanggan tersebut namun tetap berhati-hati dalam menggunakan kredit karena tidak mau membayar bunga cicilan.
#   - CASH_ADVANCE_FREQUENCY, CASH_ADVANCE_TRX: Semakin sering seorang pelanggan melakukan penarikan tunai, maka semakin loyal dan konsumtif pelanggan tersebut. Dilansir dari [Investopedia](https://www.investopedia.com/ask/answers/111414/how-does-interest-work-cash-advance-my-credit-card.asp) dan [Capital One](https://www.capitalone.com/learn-grow/money-management/cash-advance/), bank memperoleh keuntungan lebih besar melalui penarikan tunai dibandingkan melalui purchases, karena adanya biaya admin, cash advance fee dan bunga peminjaman yang lebih tinggi.
# - Nominal yang dipinjam :
#   - PURCHASES, ONEOFF_PURCHASES, INSTALLMENTS_PURCHASES, CASH_ADVANCE : Semakin banyak nominal yang dipinjam, maka semakin besar keuntungan yang diperoleh bank dari bunga peminjaman.
#   - BALANCE : meningkat ketika hutang bertambah dan menurun ketika hutang dibayarkan.
# - Total pembayaran tagihan :
#   - PAYMENTS, PRC_FULL_PAYMENT : Pelanggan yang baik adalah yang mampu membayar keseluruhan tagihannya.
#   - MINIMUM_PAYMENTS : Pelanggan yang memiliki pembayaran minimum dan selalu membayar tagihannya secara lunas lebih menguntungkan karena bank mendapatkan keuntungan tambahan dari bunga pembayaran minimum.
#
# Kolom CREDIT_LIMIT tidak dipilih karena walaupun limit yang lebih besar memang memungkinkan seseorang meminjam lebih banyak, namun dibandingkan itu, kebutuhan dan sifat konsumtif seseorang yang lebih mempengaruhi seseorang dalam menggunakan kartu kredit. Kolom TENURE juga tidak akan digunakan karena tidak sesuai dengan objektif. Selain itu, setelah dilakukan modeling, menggunakan credit limit dan tenure justru mengurangi nilai silhouette score model.
#
# **2) Seleksi atribut yang redundan**
# - Kolom PURCHASES, ONEOFF_PURCHASES, dan INSTALLMENT_PURCHASES akan digunakan karena saling berkorelasi dibawah 0.80.
# - Kolom PURCHASES_FREQUENCY akan digunakan karena berkorelasi dengan PURCHASES dibawah 0.80.
# - Kolom PURCHASES_TRX akan didrop karena berkorelasi sangat kuat terhadap PURCHASES_FREQUENCY (0.92) dan PURCHASES (0.89). Kami hanya akan menggunakan kolom PURCHASES_FREQUENCY dan PURCHASES karena dianggap telah mewakili PURCHASES_TRX.
# - Kolom ONEOFF_PURCHASES_FREQUENCY akan didrop karena berkorelasi nyaris sempurna dengan ONEOFF_PURCHASES (0.95). Kami akan menggunakan kolom ONEOFF_PURCHASES saja karena dianggap telah mewakili ONEOFF_PURCHASES_FREQUENCY. Selain itu, Bank lebih memperoleh keuntungan melalui nominal pinjaman kredit yang besar dibandingkan dengan frekuensi pembelian yang sering namun nominal pinjamannya kecil.
# - Kolom INSTALLMENT_PURCHASES_FREQUENCY akan didrop karena berkorelasi nyaris sempurna dengan INSTALLMENT_PURCHASES (0.92). Kami akan menggunakan kolom INSTALLMENT_PURCHASES saja karena dianggap telah mewakili INSTALLMENT_PURCHASES_FREQUENCY.
# - Kolom CASH_ADVANCE_TRX akan didrop karena berkorelasi sangat kuat terhadap CASH_ADVANCE_FREQUENCY (0.98) dan CASH_ADVANCE (0.95). Kolom CASH_ADVANCE_FREQUENCY juga akan di drop karena berkorelasi sebesar 0.94 terhadap CASH_ADVANCE. Kami hanya akan menggunakan kolom CASH_ADVANCE karena dianggap telah mewakili CASH_ADVANCE_TRX dan CASH_ADVANCE_FREQUENCY.
# - Kolom MINIMUM_PAYMENT akan didrop karena berkorelasi sangat kuat terhadap BALANCE (0.92).
# - Kolom PAYMENTS dan PRC_FULL_PAYMENT tetap akan digunakan.
#
# **9 kolom yang akan digunakan untuk pemodelan dengan feature selection:**
# - BALANCE
# - BALANCE_FREQUENCY
# - PURCHASES
# - ONEOFF_PURCHASES
# - INSTALLMENTS_PURCHASES
# - CASH_ADVANCE
# - PURCHASES_FREQUENCY
# - PAYMENTS
# - PRC_FULL_PAYMENT

# %% [markdown]
# ## **IV. Modeling and Evaluation**
# Algoritma yang digunakan:
# 1. K-means
#   - Metode : Elbow & Silhouette
#   - Jumlah cluster : 2,3,4,5,6
#   - Metric jarak : eucladian
# 2. Agglomerative
#   - Linkage : Ward, Complete & Average
#   - Jumlah cluster : 2,3,4,5,6
#   - Metric jarak : eucladian
# 3. DBSCAN
#   - Epsilon : 0.3,0.4,0.5,0.6
#   - Minimum sample : 15,20,25,30
#   - Metric jarak : eucladian
#
# Berikut cara kerja model dalam mensegmentasi pelanggan :
# - **K-Means** : Model akan menentukan titik centroid secara acak kemudian  mengelompokkan pelanggan berdasarkan seberapa dekat jarak antara data perilaku konsumsi kredit ke titik centroid dari sebuah cluster. Beberapa hal yang harus dipertimbangkan dalam menggunakan model ini adalah scaling, jumlah cluster optimal, metrik jarak dan metode yang digunakan (Elbow/Silhouette).
#   - **Metode Elbow** menentukan jumlah cluster optimal berdasarkan nilai within cluster sum of square (WCSS). Jumlah cluster optimal adalah ketika nilai WCSS sudah tidak berubah secara signifikan / tidak terdapat perubahan kemiripan data yang signifikan setelah penambahan 1 cluster. Semakin kecil nilai WCSS, maka semakin besar jumlah cluster optimal.
#   - **Metode Silhouette** menentukan jumlah cluster bersadarkan seberapa mirip data poin dengan clusternya sendiri dibandingkan dengan cluster lain. Nilai silhouette score berkisar antara 0-1. Semakin besar nilai silhouette score, semakin jelas perbedaan antar tiap cluster. Jika nilai silhoutte adalah 0 hingga -1, maka terdapat ketidaksesuaian antara cluster dan data poin di dalamnya.
# - **Agglomerative** : Setiap data akan bergabung dengan data yang memiliki jarak terdekat kemudian membentuk sebuah cluster. Merging akan terus dilakukan hingga tercapainya kriteria tertentu, misalnya dalam kasus ini yaitu mendapatkan cluster dengan pelanggan yang tidak terlalu bervariasi, sehingga strategi marketing dapat lebih terarah. Hal yang harus dipertimbangkan adalah ukuran dataset tidak terlalu besar, scaling, jumlah cluster, metrik jarak, serta jenis linkage (Ward/Complete/Average).
#   - **Metode ward** menggabungkan cluster berdasarkan total variance terkecil
#   - **Metode complete** menggabungkan cluster berdasarkan jarak terkecil antara 2 data terjauh antar cluster.
#   - **Metode average** menggabungkan cluster berdasarkan rata-rata jarak terkecil antara tiap data dalam 1 cluster terhadap tiap data dalam cluster lain
# - **DBSCAN** : Mengelompokkan data pelanggan yang posisinya berdekatan dengan mendefinisikan epsilon dan minimum sample. Kelebihan DBSCAN adalah dapat mendeteksi cluster yang berbentuk setengah lingkaran dan data yang tidak termasuk dalam cluster apapun (noise). Penentuan epsilon dan minimum sample harus dipertimbangkan karena semakin besar epsilon dan besar minimum sample dalam 1 cluster, maka semakin besar cluster dan semakin sedikit noise yang terdeteksi. Akibatnya, anggota cluster terlalu bervariasi.
#
# Berikut pemodelan yang akan dilakukan :
# 1. Model tanpa seleksi fitur dan PCA : K-Means, Agglomerative, DBSCAN
# 2. Model dengan seleksi fitur : K-Means
# 3. Model dengan PCA : K-Means

# %% [markdown]
# ### **Modelling Without Feature Selection and PCA (use 17 columns)**

# %%
df.shape
# Out:
# (8630, 17)

# %%
sc = RobustScaler()
df17_scaled = pd.DataFrame(sc.fit_transform(df), columns=df.columns)

# %%
def calc_vif(df):
    vif = pd.DataFrame()
    vif['variable']= df.columns
    vif['VIF'] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    vif['Acceptable'] = np.where(vif.VIF < 4, 'yes', 'no')
    return(vif)

calc_vif(df17_scaled).sort_values(by = 'VIF', ascending = False)
# Out:
#                             variable         VIF Acceptable
# 2   PURCHASES                         611.658790  no
# 3   ONEOFF_PURCHASES                  372.480896  no
# 4   INSTALLMENTS_PURCHASES            114.354866  no
# 8   PURCHASES_INSTALLMENTS_FREQUENCY  11.661021   no
# 6   PURCHASES_FREQUENCY               10.576539   no
# 9   CASH_ADVANCE_FREQUENCY            5.158197    no
# 7   ONEOFF_PURCHASES_FREQUENCY        4.533607    no
# 10  CASH_ADVANCE_TRX                  3.958294    yes
# 5   CASH_ADVANCE                      3.570820    yes
# 11  PURCHASES_TRX                     3.443880    yes
# 13  PAYMENTS                          3.017819    yes
# 0   BALANCE                           2.942355    yes
# 12  CREDIT_LIMIT                      2.183130    yes
# 15  PRC_FULL_PAYMENT                  1.760197    yes
# 1   BALANCE_FREQUENCY                 1.642395    yes
# 14  MINIMUM_PAYMENTS                  1.311725    yes
# ...

# %% [markdown]
# Terlihat setelah scaling, kolom yang bermultikolinearitas berkurang yaitu yang awalnya 12 kolom menjadi 7 kolom saja.

# %% [markdown]
# #### **1) K-Means**

# %%
def kmeans_cluster(X, n_clusters, random_state, wcss=False): 
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state, n_init='auto')
    kmeans.fit(X)
    X_cluster = X.copy()
    X_cluster['CLUSTER'] = kmeans.labels_
    X_cluster['CLUSTER'] = X_cluster['CLUSTER'].astype('category')
    if wcss == True:
        wcss_score = kmeans.inertia_
        return X_cluster, wcss_score
    return X_cluster

def kmeans_eval(X, start, stop, random_state):
    wcss = []
    silhouette = []
    membership = []
    for n in range(start, stop):
        X_cluster, wcss_score = kmeans_cluster(X, n, random_state, wcss=True)
        wcss.append(wcss_score)
        silhouette.append(silhouette_score(X, X_cluster['CLUSTER']))
        membership.append(dict(X_cluster['CLUSTER'].value_counts().sort_index()))
    evaluation = pd.DataFrame({
        'wcss': wcss,
        'silhouette': silhouette,
        'membership': membership
    }, index=range(start, stop))
    evaluation.index.set_names('n_clusters', inplace=True)
    return evaluation

# %%
fs_kmeans = kmeans_eval(df17_scaled, 2, 7, random_state=0)
fs_kmeans
# Out:
#                      wcss  silhouette  \
# n_clusters
# 2           396028.919874  0.666916
# 3           353878.749379  0.436509
# 4           296989.147223  0.271238
# 5           261837.547939  0.287342
# 6           226908.957339  0.306735
#
#                                                    membership
# n_clusters
# 2           {0: 8288, 1: 342}
# 3           {0: 7523, 1: 238, 2: 869}
# 4           {0: 6868, 1: 273, 2: 59, 3: 1430}
# 5           {0: 5756, 1: 240, 2: 1232, 3: 1347, 4: 55}
# 6           {0: 5484, 1: 23, 2: 1060, 3: 717, 4: 56, 5: 1290}

# %%
def plot_elbow(evaluation, silhouette=False):
    if silhouette == True:
        fig, ax = plt.subplots(1, 2, figsize=(16, 4))
        ax[0].title.set_text('Elbow Method')
        ax[1].title.set_text('Silhouette Score')
        sns.lineplot(ax=ax[0], data=evaluation, x=evaluation.index, y='wcss', marker='o', markersize=8)
        sns.lineplot(ax=ax[1], data=evaluation, x=evaluation.index, y='silhouette', marker='o', markersize=8)
    else:
        plt.figure(figsize=(8, 4))
        sns.lineplot(data=evaluation, x=evaluation.index, y='wcss', marker='o', markerfacecolor='tab:red', markersize=8)
    plt.xticks(ticks=evaluation.index, labels=evaluation.index)

# %%
plot_elbow(fs_kmeans, silhouette=True)

# %% [markdown]
# Silhouette score terbaik ditunjukkan oleh K-Means 2 cluster dengan nilai 0.66, kemudian K-means 3 cluster sebesar 0.43. Kedua algoritma ini dapat dipertimbangkan karena memiliki proporsi anggota cluster yang tidak mendiskriminasi. Sementara itu, K-means dengan 4, 5 dan 6 cluster memiliki nilai siluet score yang buruk (< 0.3) dan proporsi cluster yang kurang baik (terdapat cluster dengan 20-50 anggota saja sedangkan mayoritas cluster lainnya lebih dari 1000 anggota).

# %%
# Visualisasi cluster K-means 2 cluster

df_cluster = kmeans_cluster(df17_scaled, 2, 0)

df_reset = df.reset_index().drop(columns=['index'])

df_model = pd.concat([df_reset, df_cluster['CLUSTER']], axis=1)

pd.pivot_table(df_model, index='CLUSTER', aggfunc=np.mean).T
# Out:
# CLUSTER                                     0            1
# BALANCE                           1488.153410  4365.025336
# BALANCE_FREQUENCY                 0.891335     0.984191
# CASH_ADVANCE                      965.313621   1693.070860
# CASH_ADVANCE_FREQUENCY            0.138120     0.124557
# CASH_ADVANCE_TRX                  3.270874     4.380117
# CREDIT_LIMIT                      4331.609331  9215.204678
# INSTALLMENTS_PURCHASES            336.900568   2462.493684
# MINIMUM_PAYMENTS                  658.819808   5843.403538
# ONEOFF_PURCHASES                  415.684792   5200.304854
# ONEOFF_PURCHASES_FREQUENCY        0.189729     0.601099
# PAYMENTS                          1518.637436  8229.468359
# PRC_FULL_PAYMENT                  0.156320     0.232853
# PURCHASES                         752.261202   7662.798538
# PURCHASES_FREQUENCY               0.482086     0.841370
# PURCHASES_INSTALLMENTS_FREQUENCY  0.356125     0.682942
# ...

# %%
selected_cols = ['BALANCE', 'CASH_ADVANCE', 'PURCHASES', 'PAYMENTS']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
for cols, ax in zip(selected_cols, axes.flatten()):
    sns.boxplot(ax=ax, data=df_model, x='CLUSTER', y=cols, palette='Set1', showfliers=False)
axes[1].set_title('Boxplot for Model Clusters Results', size=15, loc='center')
plt.tight_layout(pad=3)

# %% [markdown]
# Tabel rata-rata data pelanggan pada tiap cluster dan hasil visualisasi clustering dengan K-Means 2 Cluster menunjukkan bahwa cluster 0 terdiri dari pelanggan yang memiliki credit limit lebih rendah dari cluster 1, sehingga total nominal penarikan tunai maupun pembeliannya cenderung rendah yaitu dibawah 2000 USD. Customer pada cluster ini cukup bertanggung jawab pada tagihan kreditnya, terlihat dari total rata-rata hutang yang dimiliki (1717.57 USD - hasil penjumlahan rata-rata cash dan purchases) dan payments / tagihan yang dibayarkan (1518.63 USD). Sementara itu, cluster 1 terdiri dari pelanggan yang memiliki nominal peminjaman diatas cluster 0, yaitu berkisar antara 4000-10.000 USD melalui transaksi dengan kartu (purchases), namun pinjaman dari tarik tunainya sama seperti cluster 0. Kekurangan dari hasil model ini adalah tidak dapat membedakan antara pelanggan yang lebih menyukai tarik tunai dengan pelanggan yang lebih menyukai bertransaksi dengan kartu.

# %%
# Visualisasi cluster K-means 3 cluster

df_cluster = kmeans_cluster(df17_scaled, 3, 0)

df_reset = df.reset_index().drop(columns=['index'])

df_model = pd.concat([df_reset, df_cluster['CLUSTER']], axis=1)

pd.pivot_table(df_model, index='CLUSTER', aggfunc=np.mean).T
# Out:
# CLUSTER                                     0             1            2
# BALANCE                           1124.583950  3721.159783   5156.240560
# BALANCE_FREQUENCY                 0.883090     0.982630      0.974251
# CASH_ADVANCE                      559.260953   774.751693    4819.146690
# CASH_ADVANCE_FREQUENCY            0.106073     0.074580      0.427619
# CASH_ADVANCE_TRX                  2.065532     2.277311      14.414269
# CREDIT_LIMIT                      3968.806079  10226.680672  7779.861910
# INSTALLMENTS_PURCHASES            344.494309   2939.308655   394.958113
# MINIMUM_PAYMENTS                  482.247243   1726.609654   3935.401005
# ONEOFF_PURCHASES                  423.024660   7180.443571   382.439275
# ONEOFF_PURCHASES_FREQUENCY        0.194562     0.781213      0.147790
# PAYMENTS                          1257.807380  9373.004831   4266.611255
# PRC_FULL_PAYMENT                  0.167847     0.336567      0.037286
# ...

# %%
selected_cols = ['BALANCE', 'CASH_ADVANCE', 'PURCHASES', 'PAYMENTS']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
for cols, ax in zip(selected_cols, axes.flatten()):
    sns.boxplot(ax=ax, data=df_model, x='CLUSTER', y=cols, palette='Set1', showfliers=False)
axes[1].set_title('Boxplot for Model Clusters Results', size=15, loc='center')
plt.tight_layout(pad=3)

# %% [markdown]
# Tabel rata-rata data pelanggan dan hasil visualisasi clustering dengan K-Means 3 Cluster menunjukkan bahwa cluster dengan kredit limit tertinggi ke terendah adalah cluster 1 (10226.68 USD), cluster 2 (7779.86 USD), lalu cluster 0 (3968.80 USD). Pelanggan dengan cluster 0 merupakan pelanggan yang jarang menggunakan kartu kredit, terlihat dari rendahnya pinjaman dari tarik tunai maupun pembelian dengan kartu kredit (< 2000 USD), sehingga balance dan paymentsnya cenderung rendah juga. Meski begitu, pelanggan pada cluster ini cukup bertanggung jawab terhadap tagihan kreditnya karena nilai paymentsnya mencapai 1257.80 USD dan rata-rata pinjamannya berada pada 1326.42 USD.
#
# Cluster 1 terdiri dari pelanggan yang lebih menyukai bertransaksi dengan kartu, sedangkan Cluster 2 terdiri dari pelanggan yang lebih menyukai tarik tunai. Pelanggan pada kedua cluster ini juga bertanggung jawab dalam membayar tagihannya, terlihat dari nominal payments yang hampir setara dengan total nominal peminjaman dari cash dan purchases. Dengan begitu, model ini dapat menjadi calon model terbaik karena dapat membedakan antara pelanggan yang jarang menggunakan kartu kredit, pelanggan yang lebih menyukai tarik tunai, dan pelanggan yang lebih suka menggunakan kartu.

# %% [markdown]
# #### **2) Agglomerative**

# %%
def agglo_cluster(X, n_clusters, linkage):
    agglo = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
    agglo.fit(X)
    X_cluster = X.copy()
    X_cluster['CLUSTER'] = agglo.labels_
    X_cluster['CLUSTER'] = X_cluster['CLUSTER'].astype('category')
    return X_cluster

def agglo_eval(X, start, stop):
    linkages = ['complete', 'average', 'ward']
    evaluation = pd.DataFrame(
        columns=pd.MultiIndex.from_product([linkages, ['silhouette', 'membership']]),
        index=range(start, stop)
    )
    i = 0
    for linkage in linkages:
        silhouette = []
        membership = []
        for n in range(start, stop):
            X_cluster = agglo_cluster(X, n, linkage)
            silhouette.append(silhouette_score(X, X_cluster['CLUSTER']))
            membership.append(dict(X_cluster['CLUSTER'].value_counts().sort_index()))
        evaluation.iloc[:, i] = silhouette
        evaluation.iloc[:, i+1] = membership
        i += 2
    evaluation.index.set_names('n_clusters', inplace=True)
    return evaluation

# %%
fs_agglo = agglo_eval(df17_scaled, 2, 7)
fs_agglo
# Out:
#              complete                                               average  \
#            silhouette                                 membership silhouette
# n_clusters
# 2           0.899661   {0: 8623, 1: 7}                            0.913193
# 3           0.856917   {0: 8604, 1: 7, 2: 19}                     0.860631
# 4           0.854889   {0: 8603, 1: 7, 2: 19, 3: 1}               0.856551
# 5           0.773152   {0: 8573, 1: 7, 2: 19, 3: 1, 4: 30}        0.825435
# 6           0.773276   {0: 7, 1: 8568, 2: 19, 3: 1, 4: 30, 5: 5}  0.812822
#
#                                                             ward  \
#                                            membership silhouette
# n_clusters
# 2           {0: 8626, 1: 4}                            0.530773
# 3           {0: 8625, 1: 4, 2: 1}                      0.493790
# 4           {0: 8607, 1: 18, 2: 1, 3: 4}               0.260954
# 5           {0: 8590, 1: 18, 2: 1, 3: 4, 4: 17}        0.266065
# ...

# %% [markdown]
# Hasil clustering dengan Agglomerative complete dan average tidak bagus karena meskipun nilai silhouette scorenya sangat bagus (seluruhnya diatas 0.77), namun pada bagian membership dapat terlihat bahwa beberapa cluster yang dibuat hanya beranggotakan kurang dari 20 pelanggan, bahkan ada cluster yang hanya beranggotakan 1 hingga 4 customer saja. Segmentasi seperti ini kurang baik diterapkan dalam bisnis karena perusahaan tidak mungkin membuat strategi bisnis hanya untuk 1 / sekumpulan kecil orang saja.
#
# Hasil algglomerative dengan nilai silhouette score terbaik namun dengan proporsi cluster yang dapat diterima terlihat pada metode ward dengan 2 maupun 3 cluster. Nilai silhouette score kedua metode ini adalah 0.53 untuk 2 cluster dan 0.49 untuk 3 cluster, dan nilai silhouette score keduanya lebih baik daripada K-means 3 cluster (0.43). Metode ward lainnya menunjukkan nilai silhouette yang sangat kecil yaitu kurang dari 0.27 yang berarti model kurang baik dalam menempatkan tiap data pelanggan terhadap clusternya.

# %%
# Visualisasi Agglomerative ward 2 cluster

df_cluster = agglo_cluster(df17_scaled, 2, 'ward')

df_reset = df.reset_index().drop(columns=['index'])

df_model = pd.concat([df_reset, df_cluster['CLUSTER']], axis=1)

pd.pivot_table(df_model, index='CLUSTER', aggfunc=np.mean).T
# Out:
# CLUSTER                                     0            1
# BALANCE                           3071.754324  1481.461448
# BALANCE_FREQUENCY                 0.984932     0.887630
# CASH_ADVANCE                      549.987672   1030.634182
# CASH_ADVANCE_FREQUENCY            0.067272     0.143357
# CASH_ADVANCE_TRX                  1.700763     3.447398
# CREDIT_LIMIT                      7614.274809  4271.426725
# INSTALLMENTS_PURCHASES            1987.244733  292.509022
# MINIMUM_PAYMENTS                  3737.998128  628.257530
# ONEOFF_PURCHASES                  3586.316855  360.459220
# ONEOFF_PURCHASES_FREQUENCY        0.571116     0.176046
# PAYMENTS                          5168.652701  1506.642975
# PRC_FULL_PAYMENT                  0.174675     0.158095
# PURCHASES                         5572.570748  652.712740
# PURCHASES_FREQUENCY               0.858594     0.466570
# PURCHASES_INSTALLMENTS_FREQUENCY  0.708759     0.341178
# ...

# %%
selected_cols = ['BALANCE', 'CASH_ADVANCE', 'PURCHASES', 'PAYMENTS']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
for cols, ax in zip(selected_cols, axes.flatten()):
    sns.boxplot(ax=ax, data=df_model, x='CLUSTER', y=cols, palette='Set1', showfliers=False)
axes[1].set_title('Boxplot for Model Clusters Results', size=15, loc='center')
plt.tight_layout(pad=3)

# %% [markdown]
# Model Agglomerative ward 2 cluster hanya dapat membagi pelanggan yang lebih menyukai tarik tunai dengan pelanggan yang lebih menyukai bertransaksi dengan kartu kredit, namun tidak dapat mengelompokkan pelanggan yang jarang menggunakan kartu kredit. Oleh karena itu, model ini tidak akan dicalonkan sebagai model terbaik.

# %%
# Visualisasi Agglomerative ward 3 cluster

df_cluster = agglo_cluster(df17_scaled, 3, 'ward')

df_reset = df.reset_index().drop(columns=['index'])

df_model = pd.concat([df_reset, df_cluster['CLUSTER']], axis=1)

pd.pivot_table(df_model, index='CLUSTER', aggfunc=np.mean).T
# Out:
# CLUSTER                                     0            1             2
# BALANCE                           1481.461448  3005.051462  3405.880588
# BALANCE_FREQUENCY                 0.887630     0.985161     0.983783
# CASH_ADVANCE                      1030.634182  470.317702   949.068444
# CASH_ADVANCE_FREQUENCY            0.143357     0.059746     0.104972
# CASH_ADVANCE_TRX                  3.447398     1.401099     3.201835
# CREDIT_LIMIT                      4271.426725  8413.278388  3611.926606
# INSTALLMENTS_PURCHASES            292.509022   2206.192637  890.496514
# MINIMUM_PAYMENTS                  628.257530   1295.711371  15971.838216
# ONEOFF_PURCHASES                  360.459220   4272.929982  146.952018
# ONEOFF_PURCHASES_FREQUENCY        0.176046     0.675713     0.047169
# PAYMENTS                          1506.642975  5884.719479  1581.749389
# PRC_FULL_PAYMENT                  0.158095     0.208422     0.005630
# ...

# %%
selected_cols = ['BALANCE', 'CASH_ADVANCE', 'PURCHASES', 'PAYMENTS']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
for cols, ax in zip(selected_cols, axes.flatten()):
    sns.boxplot(ax=ax, data=df_model, x='CLUSTER', y=cols, palette='Set1', showfliers=False)
axes[1].set_title('Boxplot for Model Clusters Results', size=15, loc='center')
plt.tight_layout(pad=3)

# %% [markdown]
# Model Agglomerative ward 3 cluster terlihat kurang dapat membedakan antara cluster 0 dan cluster 2 berdasarkan nominal cash advance, purchases maupun paymentsnya. Perbedaan yang terlihat antara cluster 0 dan 2 hanyalah pada balancenya saja, dimana cluster 2 memiliki balance yang lebih tinggi dari cluster 0. Hal ini mungkin dikarenakan pelanggan pada cluster 2 melakukan balance transfer ke kartu kredit lain sehingga balancenya pada kartu kredit ini lebih tinggi daripada total pinjamannya dari cash maupun purchases. Perbedaan antara cluster 1 dangan cluster 0 & 2 adalah cluster 1 terdiri dari pelanggan yang lebih memilih purchases, sedangkan cluster 0 & 2 lebih memilih tarik tunai. Model tidak menemukan pola pelanggan yang jarang menggunakan kartu kredit. Oleh karena itu, hasil cluster dari model ini bukanlah yang kita harapkan.

# %% [markdown]
# #### **3) DBSCAN**

# %%
def dbscan_cluster(X, epsilon, sample):
    dbscan = DBSCAN(eps = epsilon, min_samples= sample)
    dbscan.fit(X)
    X_cluster = X.copy()
    X_cluster['CLUSTER'] = dbscan.labels_
    X_cluster['CLUSTER'] = X_cluster['CLUSTER'].astype('category')
    return X_cluster

def dbscan_eval(X, start_minsample, stop_minsample, step_minsample): # Start stop_minsample adalah iterasi untuk min_samples
    epsilons = [0.3, 0.4, 0.5, 0.6]
    evaluation = pd.DataFrame(
        columns=pd.MultiIndex.from_product([epsilons, ['n_cluster', 'silhouette', 'membership']]),
        index=range(start_minsample, stop_minsample, step_minsample)
    )
    i = 0
    for epsilon in epsilons:
        n_cluster = []
        silhouette = []
        membership = []
        for n in range(start_minsample, stop_minsample, step_minsample):
          X_cluster = dbscan_cluster(X, epsilon, n)
          n_cluster.append(len(np.unique(X_cluster['CLUSTER'])))
          silhouette.append(silhouette_score(X, X_cluster['CLUSTER']))
          membership.append(dict(X_cluster['CLUSTER'].value_counts().sort_index()))
        evaluation.iloc[:, i] = n_cluster
        evaluation.iloc[:, i+1] = silhouette
        evaluation.iloc[:, i+2] = membership
        i += 3
    evaluation.index.set_names('min_samples', inplace=True)
    return evaluation

# %%
fs_dbscan = dbscan_eval(df17_scaled, 15, 31, 5)
fs_dbscan
# Out:
#                   0.3                                                      \
#             n_cluster silhouette                               membership
# min_samples
# 15           5        -0.361616   {-1: 8421, 0: 115, 1: 45, 2: 32, 3: 17}
# 20           3        -0.335925   {-1: 8487, 0: 110, 1: 33}
# 25           3        -0.337449   {-1: 8502, 0: 103, 1: 25}
# 30           2        -0.326719   {-1: 8529, 0: 101}
#
#                   0.4                                                       \
#             n_cluster silhouette                                membership
# min_samples
# 15           5        -0.368286   {-1: 8156, 0: 135, 1: 52, 2: 270, 3: 17}
# 20           5        -0.337362   {-1: 8232, 0: 43, 1: 245, 2: 86, 3: 24}
# 25           4        -0.341433   {-1: 8301, 0: 223, 1: 78, 2: 28}
# 30           3        -0.326725   {-1: 8353, 0: 218, 1: 59}
#
#                   0.5             \
#             n_cluster silhouette
# min_samples
# ...

# %% [markdown]
# Terlihat bahwa silhouette score pada seluruh metode DBSCAN yang digunakan sangat buruk karena nilainya minus. Hal ini berarti terdapat ketidaksesuaian pengelompokkan data pelanggan. Oleh karena itu, tidak terdapat model yang akan dilanjutkan ke visualisasi boxplot.

# %% [markdown]
# ### **Modelling With Feature Selection**

# %%
df9_selected = df[['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES','ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY', 'PAYMENTS', 'PRC_FULL_PAYMENT']]
df9_selected.shape
# Out:
# (8630, 9)

# %%
sc = RobustScaler()
df9_selected_scaled = pd.DataFrame(sc.fit_transform(df9_selected), columns=df9_selected.columns)

# %%
calc_vif(df9_selected_scaled).sort_values(by = 'VIF', ascending = False)
# Out:
#                  variable         VIF Acceptable
# 2  PURCHASES               212.409774  no
# 3  ONEOFF_PURCHASES        124.184526  no
# 4  INSTALLMENTS_PURCHASES  37.038617   no
# 7  PAYMENTS                2.902003    yes
# 5  CASH_ADVANCE            2.518960    yes
# 0  BALANCE                 1.900838    yes
# 8  PRC_FULL_PAYMENT        1.692294    yes
# 1  BALANCE_FREQUENCY       1.547636    yes
# 6  PURCHASES_FREQUENCY     1.524356    yes

# %% [markdown]
# Setelah feature selection rupanya masih terdapat masalah multikolinearitas, yaitu pada kolom PURCHASES, ONEOFF_PURCHASES dan INSTALLMENTS_PURCHASES. Hal ini wajar karena PURCHASES merupakan gabungan dari ONEOFF_PURCHASES dan INSTALLMENTS_PURCHASES dan korelasinya hampir mencapai 0.8. Teknik lain yang dapat dilakukan untuk menghilangkan multikolinearitas dalam data adalah dengan menghilangkan kolom yang bermultikolinearitas. Oleh karena itu, kolom ONEOFF_PURCHASES tidak akan diikutsertakan dalam pemodelan. Sebelumnya telah dicoba bahwa menghilangkan INSTALLMENTS_PURCHASES masih berpotensi adanya multikolinearitas.

# %%
df8_selected = df[['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY', 'PAYMENTS', 'PRC_FULL_PAYMENT']]
df8_selected.shape
# Out:
# (8630, 8)

# %%
sc = RobustScaler()
df8_selected_scaled = pd.DataFrame(sc.fit_transform(df8_selected), columns=df8_selected.columns)

# %%
calc_vif(df8_selected_scaled).sort_values(by = 'VIF', ascending = False)
# Out:
#                  variable       VIF Acceptable
# 2  PURCHASES               3.323767  yes
# 6  PAYMENTS                2.769922  yes
# 4  CASH_ADVANCE            2.290495  yes
# 3  INSTALLMENTS_PURCHASES  2.208567  yes
# 0  BALANCE                 1.781718  yes
# 5  PURCHASES_FREQUENCY     1.519645  yes
# 7  PRC_FULL_PAYMENT        1.429940  yes
# 1  BALANCE_FREQUENCY       1.311959  yes

# %% [markdown]
# Terlihat bahwa data telah aman dari multikolinearitas.

# %% [markdown]
# #### **1) K-Means with 9 Columns**

# %%
fs_kmeans = kmeans_eval(df9_selected_scaled, 2, 7, random_state=0)
fs_kmeans
# Out:
#                      wcss  silhouette  \
# n_clusters
# 2           237273.580693  0.340080
# 3           178041.188773  0.391685
# 4           144452.566981  0.412112
# 5           123619.314535  0.409527
# 6           106934.957751  0.402355
#
#                                                     membership
# n_clusters
# 2           {0: 7224, 1: 1406}
# 3           {0: 7043, 1: 1355, 2: 232}
# 4           {0: 6623, 1: 1319, 2: 22, 3: 666}
# 5           {0: 5966, 1: 1278, 2: 22, 3: 623, 4: 741}
# 6           {0: 5295, 1: 1147, 2: 22, 3: 478, 4: 654, 5: 1034}

# %%
plot_elbow(fs_kmeans, silhouette=True)

# %% [markdown]
# #### **2) K-Means with 8 Columns**

# %%
fs_kmeans = kmeans_eval(df8_selected_scaled, 2, 7, random_state=0)
fs_kmeans
# Out:
#                      wcss  silhouette  \
# n_clusters
# 2           173804.527771  0.378546
# 3           134638.893312  0.426712
# 4           114190.094888  0.423131
# 5           94431.827568   0.422541
# 6           90629.759269   0.355756
#
#                                                    membership
# n_clusters
# 2           {0: 6422, 1: 2208}
# 3           {0: 6962, 1: 1329, 2: 339}
# 4           {0: 6320, 1: 253, 2: 765, 3: 1292}
# 5           {0: 5378, 1: 1317, 2: 631, 3: 1219, 4: 85}
# 6           {0: 5152, 1: 1298, 2: 622, 3: 649, 4: 85, 5: 824}

# %%
plot_elbow(fs_kmeans, silhouette=True)

# %% [markdown]
# Terlihat bahwa nilai silhouette score setelah kolom ONEOFF_PURCHASES dihilangkan menjadi lebih baik pada mayoritas model. Pembagian proporsi cluster dengan K-Means juga menjadi lebih baik karena ketika ONEOFF_PURCHASES diikutsertakan, terdapat beberapa model yang masih mendiskriminasi salah satu clusternya yaitu hanya terdiri dari 22 anggota saja.
#
# Nilai silhouette score terbaik ditunjukkan oleh model K-means (8 kolom) dengan 3 cluster (0.426). Meski begitu, nilai silhouette score pada seluruh model dengan feature selection tak sebaik model K-means 3 cluster tanpa feature selection, yang berarti pengelompokkannya tak setepat K-means 3 cluster tanpa feature selection.

# %%
# Visualisasi cluster K-means 3 cluster

df_cluster = kmeans_cluster(df8_selected_scaled, 3, 0)

df_reset = df8_selected.reset_index().drop(columns=['index'])

df_model = pd.concat([df_reset, df_cluster['CLUSTER']], axis=1)

pd.pivot_table(df_model, index='CLUSTER', aggfunc=np.mean).T
# Out:
# CLUSTER                           0            1             2
# BALANCE                 1766.040206  189.131637   3776.183691
# BALANCE_FREQUENCY       0.975254     0.455788     0.969072
# CASH_ADVANCE            1014.036839  460.539301   2677.782664
# INSTALLMENTS_PURCHASES  337.573559   188.280820   3050.125133
# PAYMENTS                1469.869273  1277.695782  10234.978401
# PRC_FULL_PAYMENT        0.127506     0.282915     0.328994
# PURCHASES               809.538745   418.957976   7854.318732
# PURCHASES_FREQUENCY     0.512061     0.315540     0.881870

# %%
selected_cols = ['BALANCE', 'CASH_ADVANCE', 'PURCHASES', 'PAYMENTS']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
for cols, ax in zip(selected_cols, axes.flatten()):
    sns.boxplot(ax=ax, data=df_model, x='CLUSTER', y=cols, palette='Set1', showfliers=False)
axes[1].set_title('Boxplot for Model Clusters Results', size=15, loc='center')
plt.tight_layout(pad=3)

# %% [markdown]
# Visualisasi clustering K-Means 3 cluster (data 8 kolom) rupanya tak sebaik K-Means 3 cluster (data 17 kolom), karena model ini hanya dapat membagi pelanggan yang jarang menggunakan kartu kredit (cluster 1) dan pelanggan yang loyal & bertanggung jawab (cluster 2, berdasarkan tingginya purchases dan payments). Sementara itu, cluster 0 hanya menggambarkan pelanggan yang tingkat spendnya juga rendah dengan cash dan purchases yang tidak begitu signifikan perbedaannya.

# %% [markdown]
# ### **Modelling With PCA**

# %%
df.shape
# Out:
# (8630, 17)

# %%
sc = RobustScaler()
df_pca_scaled = sc.fit_transform(df)

pca = PCA(n_components=None, random_state=0)
pca.fit(df_pca_scaled)
df_scaled_pca = pd.DataFrame(pca.transform(df_pca_scaled))

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance')
plt.axhline(y=0.90, color='r', linestyle='-')

# %%
pca = PCA(n_components=6, random_state=0)
pca.fit(df_pca_scaled)
df_scaled_pca = pd.DataFrame(pca.transform(df_pca_scaled))
df_scaled_pca.shape
# Out:
# (8630, 6)

# %%
calc_vif(df_scaled_pca)
# Out:
#    variable  VIF Acceptable
# 0  0         1.0  yes
# 1  1         1.0  yes
# 2  2         1.0  yes
# 3  3         1.0  yes
# 4  4         1.0  yes
# 5  5         1.0  yes

# %% [markdown]
# Visualisasi grafik PCA diatas menunjukkan bahwa penggunaan 6 komponen dari PCA mampu merepresentasikan dataset ini sebesar 90% / terdapat information loss sebesar 10%. Selain itu, pada Table VIF terlihat bahwa permasalahan multikolinearitas telah diselesaikan dengan PCA.

# %% [markdown]
# #### **K-Means**

# %%
fs_kmeans = kmeans_eval(df_scaled_pca, 2, 7, random_state=0)
fs_kmeans
# Out:
#                      wcss  silhouette  \
# n_clusters
# 2           337039.558660  0.688421
# 3           300989.865664  0.552331
# 4           260416.687852  0.442054
# 5           203037.817502  0.351027
# 6           170297.961511  0.372441
#
#                                                    membership
# n_clusters
# 2           {0: 8263, 1: 367}
# 3           {0: 7862, 1: 24, 2: 744}
# 4           {0: 7046, 1: 23, 2: 761, 3: 800}
# 5           {0: 6345, 1: 23, 2: 779, 3: 59, 4: 1424}
# 6           {0: 5545, 1: 22, 2: 658, 3: 56, 4: 1300, 5: 1049}

# %%
plot_elbow(fs_kmeans, silhouette=True)

# %% [markdown]
# Terlihat bahwa model dengan nilai silhouette score dan pembagian membership terbaik ditunjukkan oleh K-Means 2 cluster. Sementara itu, model lainnya mendiskriminasi salah satu cluster.

# %%
# Visualisasi cluster K-means 2 cluster

df_cluster = kmeans_cluster(df_scaled_pca, 2, 0)

df_reset = df.reset_index().drop(columns=['index'])

df_model = pd.concat([df_reset, df_cluster['CLUSTER']], axis=1)

pd.pivot_table(df_model, index='CLUSTER', aggfunc=np.mean).T
# Out:
# CLUSTER                                     0            1
# BALANCE                           1480.721540  4336.381580
# BALANCE_FREQUENCY                 0.891083     0.983534
# CASH_ADVANCE                      955.202272   1871.152990
# CASH_ADVANCE_FREQUENCY            0.137634     0.136426
# CASH_ADVANCE_TRX                  3.251604     4.738420
# CREDIT_LIMIT                      4322.059558  9097.547684
# INSTALLMENTS_PURCHASES            333.271260   2399.412343
# MINIMUM_PAYMENTS                  651.840988   5647.358292
# ONEOFF_PURCHASES                  411.050341   4978.721662
# ONEOFF_PURCHASES_FREQUENCY        0.188803     0.593923
# PAYMENTS                          1496.515711  8270.397630
# PRC_FULL_PAYMENT                  0.156356     0.226829
# PURCHASES                         743.996461   7378.134005
# PURCHASES_FREQUENCY               0.481066     0.839852
# PURCHASES_INSTALLMENTS_FREQUENCY  0.355178     0.681999
# ...

# %%
selected_cols = ['BALANCE', 'CASH_ADVANCE', 'PURCHASES', 'PAYMENTS']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
for cols, ax in zip(selected_cols, axes.flatten()):
    sns.boxplot(ax=ax, data=df_model, x='CLUSTER', y=cols, palette='Set1', showfliers=False)
axes[1].set_title('Boxplot for Model Clusters Results', size=15, loc='center')
plt.tight_layout(pad=3)

# %% [markdown]
# K-Means 2 cluster dengan PCA hanya mampu membedakan pelanggan yang jarang menggunakan kartu kredit (cluster 0), dengan pelanggan yang loyal (cluster 1). Dengan begitu, kami memutuskan untuk memilih K-means dengan 3 cluster tanpa feature selection dan PCA sebagai final model.

# %% [markdown]
# ## **Final Model : K-Means 3 cluster without feature selection and PCA**

# %% [markdown]
# **Dataset with Cluster**

# %%
sc = RobustScaler()
df_scaled = pd.DataFrame(sc.fit_transform(df), columns=df.columns)

# %%
def final_cluster(X, n_clusters, random_state, wcss=False):
    final = KMeans(n_clusters=3, random_state=random_state, n_init='auto')
    final.fit(X)
    X_cluster = X.copy()
    X_cluster['CLUSTER'] = final.labels_
    X_cluster['CLUSTER'] = X_cluster['CLUSTER'].astype('category')
    if wcss == True:
        wcss_score = final.inertia_
        return X_cluster, wcss_score
    return X_cluster

def final_eval(X, start, stop, random_state):
    wcss = []
    silhouette = []
    membership = []
    for n in range(start, stop):
        X_cluster, wcss_score = kmeans_cluster(X, n, random_state, wcss=True)
        wcss.append(wcss_score)
        silhouette.append(silhouette_score(X, X_cluster['CLUSTER']))
        membership.append(dict(X_cluster['CLUSTER'].value_counts().sort_index()))
    evaluation = pd.DataFrame({
        'wcss': wcss,
        'silhouette': silhouette,
        'membership': membership
    }, index=range(start, stop))
    evaluation.index.set_names('n_clusters', inplace=True)
    return evaluation

# %%
df_cluster = final_cluster(df_scaled, 3, 0)
df_cluster
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -0.447975 -2.000000          -0.254662  -0.075014
# 1     1.166818 -1.000000          -0.341237  -0.075014
# 2     0.805550  0.000000           0.360412   1.213844
# 3    -0.051211  0.000000          -0.326717  -0.048342
# 4     0.455518  0.000000           0.868710  -0.075014
# ...        ...       ...                ...        ...
# 8625 -0.465866 -5.500006          -0.322270  -0.040174
# 8626 -0.454312  0.000000          -0.077046  -0.075014
# 8627 -0.456914 -1.833339          -0.210194  -0.075014
# 8628 -0.461991 -1.833339          -0.341237  -0.075014
# 8629 -0.278502 -3.666667           0.650884   1.747411
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0     0.000433                0.000000     -0.399999
# 1    -0.196419                5.685703     -0.600000
# 2    -0.196419                0.000000      0.600000
# 3    -0.196419                0.000000     -0.500000
# ...

# %% [markdown]
# **Dataset with Customer ID and Cluster**

# %%
df = pd.read_csv('CC GENERAL.csv')
df = df.dropna(subset=['CREDIT_LIMIT'])
df = df[df['CREDIT_LIMIT'] >= 200]
df = df.dropna(subset=['MINIMUM_PAYMENTS'])

df_reset = df.reset_index().drop(columns=['index'])
df_reset
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001  40.900749    0.818182           95.40      0.00
# 1     C10002  3202.467416  0.909091           0.00       0.00
# 2     C10003  2495.148862  1.000000           773.17     773.17
# 3     C10005  817.714335   1.000000           16.00      16.00
# 4     C10006  1809.828751  1.000000           1333.28    0.00
# ...      ...          ...       ...               ...     ...
# 8625  C19184  5.871712     0.500000           20.90      20.90
# 8626  C19186  28.493517    1.000000           291.12     0.00
# 8627  C19188  23.398673    0.833333           144.40     0.00
# 8628  C19189  13.457564    0.833333           0.00       0.00
# 8629  C19190  372.708075   0.666667           1093.25    1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0     95.40                   0.000000      0.166667
# 1     0.00                    6442.945483   0.000000
# ...

# %%
df_model = pd.concat([df_reset, df_cluster['CLUSTER']], axis=1)
df_model
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001  40.900749    0.818182           95.40      0.00
# 1     C10002  3202.467416  0.909091           0.00       0.00
# 2     C10003  2495.148862  1.000000           773.17     773.17
# 3     C10005  817.714335   1.000000           16.00      16.00
# 4     C10006  1809.828751  1.000000           1333.28    0.00
# ...      ...          ...       ...               ...     ...
# 8625  C19184  5.871712     0.500000           20.90      20.90
# 8626  C19186  28.493517    1.000000           291.12     0.00
# 8627  C19188  23.398673    0.833333           144.40     0.00
# 8628  C19189  13.457564    0.833333           0.00       0.00
# 8629  C19190  372.708075   0.666667           1093.25    1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0     95.40                   0.000000      0.166667
# 1     0.00                    6442.945483   0.000000
# ...

# %%
# Download to csv
df_model.to_csv('df_finalmodel_creditcard.csv', index=False)
from google.colab import files
files.download('df_finalmodel_creditcard.csv')

# %% [markdown]
# **K-Means 3 Cluster Detail Analysis**

# %%
# Evaluation Result
fs_final = final_eval(df_scaled, 3,4,0)
fs_final
# Out:
#                      wcss  silhouette                 membership
# n_clusters
# 3           353878.749379  0.436509    {0: 7523, 1: 238, 2: 869}

# %%
df_model['CLUSTER'].value_counts()
# Out:
# 0    7523
# 2    869
# 1    238
# Name: CLUSTER, dtype: int64

# %%
# Table mean of columns for each cluster
pd.pivot_table(df_model, index='CLUSTER', aggfunc=np.mean).T
# Out:
# CLUSTER                                     0             1            2
# BALANCE                           1124.583950  3721.159783   5156.240560
# BALANCE_FREQUENCY                 0.883090     0.982630      0.974251
# CASH_ADVANCE                      559.260953   774.751693    4819.146690
# CASH_ADVANCE_FREQUENCY            0.106073     0.074580      0.427619
# CASH_ADVANCE_TRX                  2.065532     2.277311      14.414269
# CREDIT_LIMIT                      3968.806079  10226.680672  7779.861910
# INSTALLMENTS_PURCHASES            344.494309   2939.308655   394.958113
# MINIMUM_PAYMENTS                  482.247243   1726.609654   3935.401005
# ONEOFF_PURCHASES                  423.024660   7180.443571   382.439275
# ONEOFF_PURCHASES_FREQUENCY        0.194562     0.781213      0.147790
# PAYMENTS                          1257.807380  9373.004831   4266.611255
# PRC_FULL_PAYMENT                  0.167847     0.336567      0.037286
# ...

# %%
# K-Means 3 Cluster visualization
selected_cols = ['BALANCE', 'CASH_ADVANCE', 'PURCHASES', 'PAYMENTS']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
for cols, ax in zip(selected_cols, axes.flatten()):
    sns.boxplot(ax=ax, data=df_model, x='CLUSTER', y=cols, palette='Set1', showfliers=False)
axes[1].set_title('Boxplot for Model Clusters Results', size=15, loc='center')
plt.tight_layout(pad=3)

# %% [markdown]
# Hasil visualisasi dari model terbaik menunjukkan bahwa dari total 8.630 pelanggan kartu kredit dapat disegmentasikan menjadi 3 kelompok yaitu :
# - Cluster 0 : General User
# - Cluster 1 : High Purchase
# - Cluster 2 : High Cash Advance
#
# #### **Karakteristik Cluster**
# **1. General User :**
#   - Anggotanya paling banyak diantara kedua cluster lainnya (87.17%).
#   - Memiliki rata-rata credit limit paling rendah (sekitar 3000 USD).
#   - Memiliki rata-rata nominal pinjaman yang rendah (sekitar 1000 USD), baik itu dari purchases/pembelian maupun cash advances/tarik tunai, dan dari jumlah transaksinya (14 kali/6 bulan) terlihat jarang menggunakan kartu kredit, sehingga diperkirakan merupakan pengguna yang alat transaksi utamanya bukan kartu kredit.
#   - Termasuk low value customer karena meskipun jumlahnya banyak tetapi memiliki perputaran uang yang paling sedikit.
#
# **2. High Purchase :**
#   - Jumlahnya paling sedikit diantara kedua cluster lainnya (2.76%).
#   - Memiliki rata-rata credit limit paling tinggi (sekitar 10.000 USD).
#   - Memiliki rata-rata nominal pinjaman paling besar (diatas 10.000 USD) yang mayoritas berasal dari purchases/pembelian. Hampir 10 kali lipat dari cluster General User.
#   - Paling sering melakukan purchases dan jarang melakukan tarik tunai.
#   - Memiliki rata-rata transaksi 100 kali/6 bulan, yang berarti pengguna tak hanya memiliki nominal peminjaman yang besar namun juga sering bertransaksi menggunakan kartu kredit, maka dapat dikatakan pengguna pada cluster ini konsumtif dan loyal.
#   - Pelanggan pada cluster ini menyukai bertransaksi dengan 1 kali bayar maupun dengan cicilan, terlihat dari rata-rata frekuensi one off purchases (0.78) dan frekuensi installment purchases (0.72) yang tinggi.
#   - Memiliki rata-rata payments tertinggi dan lebih besar dari balance/saldo kredit-nya, artinya cluster ini disiplin membayar tagihan kredit. Sehingga cluster ini dapat dikatakan sebagai high value customer.
#
# **3. High Cash Advance :**
#   - Jumlahnya 10.07% dari total keseluruhan customer.
#   - Memiliki rata-rata credit limit sekitar 7000 USD.
#   - Memiliki rata-rata nominal tarik tunai paling besar, dan paling sering melakukan tarik tunai. Namun jarang melakukan purchases.
#   - Memiliki rata-rata pinjaman sekitar 5500 USD atau lebih besar 5 kali lipat dari cluster general user dan rata-rata transaksi sebanyak 17 kali/6 bulan, sehingga customer ini cenderung meminjam dalam jumlah besar dalam sekali transaksi.
#   - Memiliki rata-rata pinjaman yang lebih tinggi daripada payments-nya, dan rata-rata minimum payments-nya juga tertinggi. Artinya cluster ini memiliki lebih banyak pinjaman dibandingkan kemampuan melunasinya.

# %% [markdown]
# ## **V. Conclusion**
# - Pelanggan kartu kredit disegmentasikan menjadi 3 kelompok, yaitu :
#     - Cluster 0 = General User
#     - Cluster 1 = High Purchase
#     - Cluster 2 = High Cash Advance
# - Model yang digunakan untuk clustering adalah K-Means 3 Cluster tanpa feature selection dan PCA.
# - Model ini hanya dapat digunakan pada data pelanggan dengan nilai maximum dan minimum pada tiap variabel berikut / penggunaannya menjadi tidak valid jika nilai datanya diluar jangkauan ini:
#     1. BALANCE : 0 hingga 19.043 USD
#     1. BALANCE_FREQUENCY : 0 hingga 1
#     1. PURCHASES : 0 hingga 49.039 USD
#     1. ONEOFF_PURCHASES : 0 hingga 40.761 USD
#     1. INSTALLMENTS_PURCHASES : 0 hingga 22.500 USD
#     1. CASH_ADVANCE : 0 hingga 47.137 USD
#     1. PURCHASES_FREQUENCY : 0 hingga 1
#     1. ONEOFF_PURCHASES_FREQUENCY : 0 hingga 1
#     1. PURCHASES_INSTALLMENTS_FREQUENCY : 0 hingga 1
#     1. CASH_ADVANCE_FREQUENCY : 0 hingga 1.5
#     1. CASH_ADVANCE_TRX : 0 hingga 123 kali transaksi
#     1. PURCHASES_TRX : 0 hingga 358 kali transaksi
#     1. CREDIT_LIMIT : 200 hingga 30.000 USD
#     1. PAYMENTS : 0.049513 hingga 50.721 USD
#     1. MINIMUM_PAYMENTS : 0.019163 hingga 76.406 USD
#     1. PRC_FULL_PAYMENT : 0 hingga 1
#     1. TENURE : 6 hingga 12 bulan
# - Model juga hanya berlaku untuk data pelanggan periode 6 bulan, tidak boleh kurang atau lebih.

# %% [markdown]
# ## **VI. Recommendation**
#
# #### **Rekomendasi Bisnis**
# Berdasarkan karakteristik tiap cluster, strategi marketing yang dapat dilakukan adalah:
#
# **1. General User :**
#
# Tujuan strategi marketing untuk cluster ini adalah untuk membuat user semakin tertarik bertransaksi menggunakan credit card (retain), yaitu dengan :
#    - Sistem reward (low level) jika sudah mencapai beberapa kali transaksi dgn kartu kredit
#    - 0% installment program (dengan nominal minimum purchase yang tidak terlalu tinggi)
#    - Cashback (low nominal) jika melakukan transaksi purchase ataupun cash advance
#
# **2. High Purchase :**
#
# Tujuan strategi marketing untuk cluster ini adalah untuk membuat user tetap loyal dalam melakukan transaksi dengan kartu kredit dan meningkatkan ketertarikan user untuk melakukan tarik tunai, yaitu dengan :
#   - Sistem reward (high level) jika sudah mencapai beberapa kali transaksi dgn kartu kredit
#   - Memberikan reward saat menggunakan cash advance dengan nominal tertentu, karena user jarang menggunakan cash advance namun memiliki riwayat purchases tinggi, sebenarnya user ini berpotensi untuk memberikan keuntungan lebih bagi bank jika tertarik untuk melakukan cash advance juga.
#   - 0% installment program (dengan nominal minimum purchase yang lebih tinggi)
#   - Cashback (high nominal) jika melakukan transaksi purchases dan cash advance
#   - Bekerja sama dengan merchant yang sesuai dengan data riwayat transaksi customer. Ketika jumlah transaksi jual beli antara customer dengan sebuah merchant tinggi, maka merchant tersebut dapat dijadikan pertimbangan untuk kolaborasi, yaitu memberikan reward/minimum interest/cashback pada pembelian minimal. Penentuan pembelian minimum sebaiknya lebih tinggi dari rata-rata purchases agar dapat memicu customer tersebut untuk spend lebih banyak sebelum mendapat benefit. Selain itu, penawaran yang diberikan juga lebih terarah / user based.
#   - Menawarkan Overlimit maupun kenaikan credit limit bagi pelanggan yang memang konsisten jumlah transaksi pembeliannya besar dan selalu membayarkan tagihannya secara lunas (dengan pengamatan minimal 2-3 bulan).
#
#
# **3. High Cash Advance :**
#
# Tujuan strategi marketing untuk cluster ini adalah untuk membuat user semakin loyal melakukan tarik tunai dan meningkatkan penggunaan kartu kredit untuk pembayaran juga, yaitu dengan :
#   - Sistem reward (Medium level) jika sudah mencapai beberapa kali transaksi dgn kartu kredit
#   - 0% installment program (dengan nominal minimum purchase yang rendah), karena purchases pada cluster ini cenderung rendah maka bisa diawali dengan minimum purchase yang rendah
#   - Cashback (Medium nominal) jika melakukan transaksi purchases dan cash advance dengan nominal tertentu
#   - Menawarkan Cash Advance program bagi pelanggan yang memang konsisten jumlah transaksi tarik tunainya besar dan selalu membayarkan tagihannya secara lunas (dengan pengamatan minimal 2-3 bulan). Program ini memberikan benefit admin fee yang lebih rendah.
#
# ####**Rekomendasi untuk pengembangan model**
# - Menambahkan kolom-kolom baru yang berhubungan dengan perilaku pelanggan secara lebih mendetail, seperti jenis kartu kredit, tanggal terjadinya transaksi, nominal uang yang dikeluarkan untuk tiap transaksi, nama aset/produk/tempat yang dibeli menggunakan kredit, sehingga proses data cleaning dapat dilakukan secara lebih subjektif, silhouette score dapat ditingkatkan dan pemberian strategi bisnis dapat lebih terarah.
# - Mencoba algorithma mechine learning clustering lainnya, seperti Gaussian Mixture, BIRCH, dan Mini-Batch K-Means.
# - Mencoba metric evaluasi lain seperti Dunn’s Index (DI)
# - Menggunakan Mahalanobis distance untuk K-Means, berdasarkan penelitian yang dilakukan oleh [Rajan Sambandam](https://trcmarketresearch.com/whitepaper/cluster-analysis-gets-complicated/), multikolinearitas berpengaruh terhadap Eucledian distance namun tidak terhadap Mahalanobis distance. Ukuran dataset perlu dipertimbangkan sebab kekurangan menggunakan konsep jarak Mahalanobis adalah membutuhkan waktu komputasi yang lebih panjang.

# %% [markdown]
# ## **VII. Business Implementation**

# %% [markdown]
# #### **1) Gaining Retention Rate**
#
# Rekomendasi yang dihasilkan tentunya bertujuan agar pengguna tetap menggunakan kartu kredit atau tidak churn.
# - Berdasarkan [Statista](https://www.statista.com/statistics/1041645/customer-retention-rates-by-industry-worldwide/), retention rate pada banking industry sebesar 75% pada tahun 2018.
# - Dilansir dari [Bain & Company](https://www.bain.com/client-results/right-value-for-the-right-customers/), studi kasus dilakukan terhadap sebuah bank bernama PiggyBank. Dengan meningkatkan customer relationship, retention rate meningkat 4% dan berdampak pada kenaikan profit sebesar 11%.
# - Berdasarkan artikel [Harvard Business School](https://hbswk.hbs.edu/archive/the-economics-of-e-loyalty), kenaikan customer retention rate sebesar 5% dapat meningkatkan profit 25% sampai 95%.
# - Berdasarkan [Database Marketing Institute](http://www.dbmarketing.com/articles/Art175.htm) "It costs about 80 USD to acquire a new credit card customer who returns about 120 USD per year in profit, but only if she keeps the card. If she drops the card after a few weeks, or doesn’t use the card, the issuer will lose that 80 USD, plus some more money spent trying to reactivate her. It is a tough business.'' Sehingga bisa dikatakan profit dalam setahun yang didapatkan dari seorang user yang retain adalah sebesar 120 USD per tahun. Karena data yang kita miliki adalah 6 bulan sehingga kita mengasumsikan profitnya menjadi 60 USD.
#
# **Asumsi:**
#
# Final model diasumsikan berdampak pada peningkatan retention rate secara keseluruhan dan diasumsikan retention rate meningkat sebesar 4% - 5%. Kemudian kita dapat mengestimasi profit yang didapatkan dengan mengkalikan jumlah customer, profit, dan retention rate.

# %%
user = 8630
profit = 60
retention_rate = 0.75

# Profit awal (sebelum clustering)
est_profit_awal = user*profit*retention_rate

# Profit setelah clustering
# Retention rate meningkat 4%
est_profit_4 = user*profit*(retention_rate+0.04)
# Retention rate meningkat 5%
est_profit_5 = user*profit*(retention_rate+0.05)

persen_profit_4 = (est_profit_4-est_profit_awal)*100/est_profit_awal
persen_profit_5 = (est_profit_5-est_profit_awal)*100/est_profit_awal

print(f'Estimasi profit awal yang dihasilkan oleh Bank selama 6 bulan adalah', est_profit_awal,'USD')
print(f'Estimasi profit yang dihasilkan oleh Bank selama 6 bulan setelah retention rate meningkat 4% adalah', est_profit_4,'USD')
print(f'Estimasi profit yang dihasilkan oleh Bank selama 6 bulan setelah retention rate meningkat 5% adalah', est_profit_5,'USD')
print(f'Dengan asumsi segmentasi/clustering dengan model dapat meningkatkan retention rate 4% - 5%, maka profit meningkat sebesar', round(persen_profit_4,2) ,'% sampai', round(persen_profit_5,2), '%')
# Out:
# Estimasi profit awal yang dihasilkan oleh Bank selama 6 bulan adalah 399150.0 USD
# Estimasi profit yang dihasilkan oleh Bank selama 6 bulan setelah retention rate meningkat 4% adalah 420438.0 USD
# Estimasi profit yang dihasilkan oleh Bank selama 6 bulan setelah retention rate meningkat 5% adalah 425760.0 USD
# Dengan asumsi segmentasi/clustering dengan model dapat meningkatkan retention rate 4% - 5%, maka profit meningkat sebesar 5.33 % sampai 6.67 %

# %% [markdown]
# #### **2) Reduce Marketing Cost**
#
# Persebaran Cluster:
# - General User: 7523
# - High Purchase: 238
# - High Cash Advance: 869
#
# **Asumsi:**
# - Marketing cost dinotasikan dengan X
# - Marketing cost pada cluster 0 adalah sebesar 1X karena nilai dari campaign seperti cashback dan reward bersifat low.
# - Marketing cost pada cluster 1 dan 2 adalah sebesar 1,25X karena effort dari campaign lebih besar dibanding dengan cluster 0
#
# Jika kita tidak melakukan segmentasi atau clustering, kecenderungan yang akan dilakukan adalah menggunakan marketing cost 1,25X karena kita tidak tahu segmentasi mana yang perlu effort lebih sedikit. Sehingga kecenderungan secara konservatif akan memilih 1,25X. Sehingga marketing cost total sebesar:
#
# (7523 + 238 + 869) * 1,25X = 10787,5 X
#
# Sedangkan setelah kita melakukan segmentasi, kita mengetahui customer mana yang bisa ditreat lebih tepat dengan effort yang lebih rendah. Sehingga marketing cost menjadi:
#
# 7523 * X + (238 + 869) * 1,25X = 8906,75 X
#
# Sehingga secara perhitungan kita dapat save marketing cost sekitar 17,43%

# %%
cluster0 = 7523
cluster1 = 238
cluster2 = 869

cost_tanpa_model = (cluster0+cluster1+cluster2)*1.25
cost_dengan_model = cluster0 + (cluster1+cluster2)*1.25

save = (cost_tanpa_model-cost_dengan_model)/cost_tanpa_model*100

print(f'Marketing cost yang dibutuhkan jika tidak membuat model (konservatif) adalah', cost_tanpa_model, 'X')
print(f'Marketing cost yang dibutuhkan setelah membuat model adalah', cost_dengan_model, 'X')
print(f'Sehingga dengan membuat model, kita dapat save marketing cost sekitar', round(save,2), '%')
# Out:
# Marketing cost yang dibutuhkan jika tidak membuat model (konservatif) adalah 10787.5 X
# Marketing cost yang dibutuhkan setelah membuat model adalah 8906.75 X
# Sehingga dengan membuat model, kita dapat save marketing cost sekitar 17.43 %
